# %% [markdown]
# ## Setting

# %% [markdown]
# ### Importing Dependencies

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\jjska\anaconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\jjska\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in c:\users\jjska\anaconda3\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\jjska\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\jjska\anaconda3\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: colorama in c:\users\jjska\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
import pandas as pd
import numpy as np

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_score
from sklearn.metrics.pairwise import cosine_similarity

from wordcloud import WordCloud

import matplotlib.pyplot as plt

# %%
nltk.download('stopwords')
nltk.download('wordnet')

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HanGeunHyeong\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\HanGeunHyeong\AppData\Roaming\nltk_data...

# %% [markdown]
# ### Data Load & Cleaning

# %%
data = pd.read_csv("Total_Dataset.csv")
data.head()
# Out:
#                                        Authors  \
# 0                       Zhu, X; Xu, ZF; Hu, MD
# 1     Kazanavicius, E; Imbrasas, D; Razukas, M
# 2                     Wang, XD; Tao, Y; Xu, XW
# 3  Maamar, Z; Mahmoud, Q; Sahli, N; Boukadi, K
# 4                                       Kim, E
#
#                                        Article_Title Conference Title  \
# 0  The development for Internet of Things smart h...              NaN
# 1  Service Provisioning Framework for Digital Sma...              NaN
# 2          SHSM: A Service Middleware for Smart Home              NaN
# 3          Privacy-Aware Web Services in Smart Homes              NaN
# 4  Smart City Service Platform Associated with Sm...              NaN
#
#   Conference Title.1 Conference Sponsor Conference Host  \
# 0                NaN                NaN             NaN
# 1                NaN                NaN             NaN
# 2                NaN                NaN             NaN
# 3                NaN                NaN             NaN
# 4                NaN                NaN             NaN
#
#                                      Author Keywords Keywords Plus  \
# 0                 IoT; smart home; service; platform           NaN
# 1  smart home; service provisioning; distributed ...           NaN
# 2  Smart Home; Service Middleware; Service Comput...           NaN
# 3    Policy; Privacy; Smart Home; Trust; Web service           NaN
# 4  smart city service platform; smart home; inter...           NaN
#
#                                             Abstract Addresses  ...  \
# 0  Internet of things smart home integrates autom...       NaN  ...
# 1  Development and Management Framework of Smart ...       NaN  ...
# 2  There emerges an increasing need to overcome t...       NaN  ...
# 3  Smart homes can assist their inhabitants with ...       NaN  ...
# 4  This paper proposes an intelligent smart city ...       NaN  ...
#
#   Web of Science Index Research Areas IDS Number Pubmed Id  \
# 0                  NaN            NaN        NaN       NaN
# 1                  NaN            NaN        NaN       NaN
# 2                  NaN            NaN        NaN       NaN
# 3                  NaN            NaN        NaN       NaN
# 4                  NaN            NaN        NaN       NaN
#
#   Open Access Designations Highly Cited Status Hot Paper Status  \
# 0                      NaN                 NaN              NaN
# 1                      NaN                 NaN              NaN
# 2                      NaN                 NaN              NaN
# 3                      NaN                 NaN              NaN
# 4                      NaN                 NaN              NaN
#
#   Date of Export UT (Unique WOS ID)               Web of Science Record
# 0            NaN                NaN  View Full Record in Web of Science
# 1            NaN                NaN  View Full Record in Web of Science
# 2            NaN                NaN  View Full Record in Web of Science
# 3            NaN                NaN  View Full Record in Web of Science
# 4            NaN                NaN  View Full Record in Web of Science
#
# [5 rows x 59 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4766 entries, 0 to 4765
# Data columns (total 59 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Authors                     4766 non-null   object
#  1   Article_Title               4766 non-null   object
#  2   Conference Title            4 non-null      object
#  3   Conference Title.1          4 non-null      object
#  4   Conference Sponsor          4 non-null      object
#  5   Conference Host             4 non-null      object
#  6   Author Keywords             4021 non-null   object
#  7   Keywords Plus               2473 non-null   object
#  8   Abstract                    4758 non-null   object
#  9   Addresses                   4 non-null      object
#  10  Affiliations                4 non-null      object
#  11  Reprint Addresses           4 non-null      object
#  12  Email Addresses             4 non-null      object
#  13  Researcher Ids              4 non-null      object
#  14  ORCIDs                      4 non-null      object
#  15  Funding Orgs                4 non-null      object
#  16  Funding Name Preferred      4 non-null      object
#  17  Funding Text                4 non-null      object
#  18  Cited References            4 non-null      object
#  19  Cited Reference Count       4 non-null      object
#  20  Times Cited, WoS Core       4 non-null      object
#  21  Times Cited, All Databases  4 non-null      object
#  22  180 Day Usage Count         4 non-null      object
#  23  Since 2013 Usage Count      4 non-null      object
#  24  Publisher                   4 non-null      object
#  25  Publisher City              4 non-null      object
#  26  Publisher Address           4 non-null      object
#  27  ISSN                        4 non-null      object
#  28  eISSN                       4 non-null      object
#  29  ISBN                        4 non-null      object
#  30  Journal Abbreviation        4 non-null      object
#  31  Journal ISO Abbreviation    4 non-null      object
#  32  Publication Date            4 non-null      object
#  33  Publication Year            4 non-null      object
#  34  Volume                      4 non-null      object
#  35  Issue                       4 non-null      object
#  36  Part Number                 4 non-null      object
#  37  Supplement                  4 non-null      object
#  38  Special Issue               4 non-null      object
#  39  Meeting Abstract            4 non-null      object
#  40  Start Page                  4 non-null      object
#  41  End Page                    4 non-null      object
#  42  Article Number              4 non-null      object
#  43  DOI                         4 non-null      object
#  44  DOI Link                    4 non-null      object
#  45  Book DOI                    4 non-null      object
#  46  Early Access Date           4 non-null      object
#  47  Number of Pages             4 non-null      object
#  48  WoS Categories              4 non-null      object
#  49  Web of Science Index        4 non-null      object
#  50  Research Areas              4 non-null      object
#  51  IDS Number                  4 non-null      object
#  52  Pubmed Id                   4 non-null      object
#  53  Open Access Designations    4 non-null      object
#  54  Highly Cited Status         4 non-null      object
#  55  Hot Paper Status            4 non-null      object
#  56  Date of Export              4 non-null      object
#  57  UT (Unique WOS ID)          4 non-null      object
#  58  Web of Science Record       4766 non-null   object
# dtypes: object(59)
# memory usage: 2.1+ MB

# %%
data.dropna(subset=['Abstract'], inplace=True)
data.drop_duplicates(subset=['Article_Title'], inplace=True)

# %%
data.shape
# Out:
# (4743, 59)

# %%
def combine_2rd_columns(col_1, col_2):
    result = col_1
    if not pd.isna(col_2):
        result += " " + str(col_2)
    return result


# data = pd.read_csv("pilot_textming.csv")
data["text"] = data.apply(lambda x: combine_2rd_columns(x['Article_Title'], x['Abstract']), axis=1)

df = data.loc[:, ['text']]
df.tail()
# Out:
#                                                    text
# 4761  Estimated stroke risk, yield, and number neede...
# 4762  The global burden of childhood and adolescent ...
# 4763  Global, regional, and national incidence, prev...
# 4764  Global, regional, and national age-sex-specifi...
# 4765  Global, regional, and national age-sex-specifi...

# %%
df.drop_duplicates(subset=['text'], inplace=True)

# %%
df.shape
# Out:
# (4743, 1)

# %% [markdown]
# #### Data Preprocess

# %%
def preprocess_text(text):
    # 소문자 변환 및 토큰화 (단어 단위로 분할)
    tokens = text.lower().split()
    
    # Stopword 제거 및 Lemmatization 수행
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens if token not in stop_words]
    
    # Stemming 수행 (Porter Stemmer 사용)
    stemmer = PorterStemmer()
    tokens = [stemmer.stem(token) for token in tokens]
    
    # 숫자 제거 및 재결합하여 문자열 반환
    processed_text = ' '.join([token for token in tokens if not token.isdigit()])
    
    return processed_text

df['processed_text'] = df['text'].apply(preprocess_text)
df = df.loc[:, ['processed_text']]
df.head()
# Out:
#                                       processed_text
# 0  develop internet thing smart home servic oper ...
# 1  servic provis framework digit smart home servi...
# 2  shsm: servic middlewar smart home emerg increa...
# 3  privacy-awar web servic smart home smart home ...
# 4  smart citi servic platform associ smart home p...

# %%
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(df['processed_text'])
tfidf_matrix
# Out:
# <4743x18702 sparse matrix of type '<class 'numpy.float64'>'
# 	with 425053 stored elements in Compressed Sparse Row format>

# %% [markdown]
# #### Selected only the word-features - based on TF-IDF(Python scikit-Learn Library)

# %%
# 상위 Docuement 당 TF-IDF 기반 상위 4개의 단어 추출 함수 정의

top_keywords_per_document = []
feature_names = tfidf_vectorizer.get_feature_names_out()

for i in range(len(df)):
    tfidf_scores = zip(feature_names, tfidf_matrix[i].toarray()[0])
    sorted_tfidf_scores = sorted(tfidf_scores,key=lambda x: x[1], reverse=True)
    top_keywords_per_document.append([keyword for keyword,_ in sorted_tfidf_scores[:4]])

# 전체 데이터셋에서 적어도 2번 이상 나온 키워드 추출하기 
all_keywords=[keyword for document in top_keywords_per_document for keyword in document]
selected_keywords=list(set(keyword for keyword in all_keywords if all_keywords.count(keyword) >=2))

# 선택된 키워드를 기반으로 Document-Term Matrix 생성
vectorizer=CountVectorizer(vocabulary=selected_keywords)
document_term_matrix=vectorizer.fit_transform(df['processed_text'])

# WordCloud 시각화 함수 정의 및 실행   
def visualize_wordcloud(keywords):
     wordcloud=WordCloud(background_color='white', width=800,height=400).generate(' '.join(keywords))
     plt.imshow(wordcloud.recolor(colormap='viridis',random_state=42),interpolation="bilinear")
     plt.axis("off")
     plt.show()

visualize_wordcloud(selected_keywords)
document_term_matrix
# Out:
# <4743x2204 sparse matrix of type '<class 'numpy.int64'>'
# 	with 271682 stored elements in Compressed Sparse Row format>

# %%
# # 재정규화된 TF-IDF 값으로 단어 분포 확인
# renormalized_tfidf_matrix = tfidf_matrix / tfidf_matrix.sum(axis=1)
# word_distribution_per_document = renormalized_tfidf_matrix.A # .A to convert sparse matrix to numpy array

# print("Word Distribution per Document:")
# for i in range(len(df)):
#     print(f"Document {i+1}:")
    
# word_distribution_pairs = zip(feature_names, word_distribution_per_document[i])
# sorted_word_distribution_pairs = sorted(word_distribution_pairs,key=lambda x: x[1], reverse=True)

# for word,distribution in sorted_word_distribution_pairs:
#         print(f"{word}: {distribution}")

# %% [markdown]
# #### Gaussian mixture model (GMM) Elimniated Type 1 & Type 2

# %%
# 키워드들의 TF-IDF 벡터를 가져옵니다.
selected_keywords_list = list(selected_keywords)
selected_keyword_indices = [np.where(feature_names == keyword)[0][0] for keyword in selected_keywords_list]
selected_tfidf_vectors = tfidf_matrix[:, selected_keyword_indices].toarray()

# GMM 클러스터링을 수행합니다. 
n_clusters = 100 # 임의로 설정한 클러스터 개수
gmm = GaussianMixture(n_components=n_clusters)
gmm.fit(selected_tfidf_vectors)

# 각 클러스터에 속하는 단어들의 리스트를 생성합니다.
clusters = [[] for _ in range(n_clusters)]
labels = gmm.predict(selected_tfidf_vectors)
for word, label in zip(selected_keywords_list, labels):
    clusters[label].append(word)

# 10번의 클러스터링 분석을 수행하고, 일관되게 중요하지 않다고 판단되는 단어들을 추출합니다.
non_important_words_sets = []
for _ in range(10):
    gmm.fit(selected_tfidf_vectors)
    labels = gmm.predict(selected_tfidf_vectors)
    
    # 가장 큰 클러스터를 '중요하지 않은' 단어들로 간주합니다.
    largest_cluster_label = np.bincount(labels).argmax()
    non_important_words_sets.append(set(word for i, word in enumerate(selected_keywords_list) if labels[i] != largest_cluster_label))

# 모든 실행에서 공통적으로 중요하지 않다고 판단된 단어들만 추출합니다.
common_non_important_words_set = set.intersection(*non_important_words_sets)

print("Common Non-Important Words:")
for word in common_non_important_words_set:
    print(word)

# 선택된 키워드 목록에서 공통적으로 중요하지 않은 단어들을 제거합니다.
final_selected_keywords_set = set(selected_keywords_list) - common_non_important_words_set

print("\nFinal Selected Keywords:")
for word in final_selected_keywords_set:
    print(word)

# %%
print(len(final_selected_keywords_set))
# Out:
# 407

# %%
# Document-Term Matrix에서 각 키워드별로 평균 TF-IDF 값을 계산합니다.
vectorizer = TfidfVectorizer(vocabulary=final_selected_keywords_set)

tfidf_matrix = vectorizer.fit_transform(df['processed_text'])  # 'documents'는 문서 리스트입니다.

avg_tfidf_values = tfidf_matrix.mean(axis=0).A1  # 'A1'은 numpy array를 1차원으로 변환합니다.

keyword_tfidf_dict = dict(zip(vectorizer.get_feature_names_out(), avg_tfidf_values))

for word, value in keyword_tfidf_dict.items():
    if np.isnan(value):
        print(f"'{word}' has a TF-IDF value of NaN.")
        keyword_tfidf_dict[word] = 0
        
# 워드 클라우스 객체 생성
wordcloud = WordCloud(width=800, height=400, background_color='white')

# 선택된 키워트들과 그들의 평균 TF-IDF 값으로부터 워드클라우스 이미지 생성
wordcloud.generate_from_frequencies(frequencies=keyword_tfidf_dict)

# 워듣클라우스 시각화
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# #### Eliminated outliers by calculating the cosine similarities

# %%
# 1. TF-IDF 값을 다시 계산합니다.
vectorizer = TfidfVectorizer(vocabulary=final_selected_keywords_set)
tfidf_matrix = vectorizer.fit_transform(df["processed_text"])

# 2. 각 데이터 항목(문서) 간의 코사인 유사도를 계산합니다.
cosine_sim_matrix = cosine_similarity(tfidf_matrix)

# 3. 코사인 유사도가 특정 임곗값보다 높은(즉, 문서들이 매우 비슷한) 데이터 항목들을 제거합니다.
threshold = 0.8  # 임곗값 설정
outlier_indices = []

for i in range(len(df)):
    for j in range(i+1, len(df)):
        if cosine_sim_matrix[i][j] > threshold:
            outlier_indices.append(j)

# 중복된 인덱스 제거
outlier_indices = list(set(outlier_indices))

# 이상치 아닌 문서만 선택하여 최종 문서 집합 생성
final_documents = [doc for i, doc in enumerate(df["processed_text"]) if i not in outlier_indices]

# %% [markdown]
# ### Descriptive analysis - Spectral Clustering

# %%
from sklearn.cluster import SpectralClustering
from sklearn.metrics import silhouette_score, pairwise_distances
import numpy as np
import matplotlib.pyplot as plt

# 클러스터 개수 범위 설정 (2부터 50까지)
cluster_range = range(2, 51)

# 각 클러스터 개수별로 Silhouette 평균 값을 기록할 리스트 초기화
silhouette_scores_cosine = []
silhouette_scores_euclidean = []

# 선택된 키워드들을 기반으로 Spectral Clustering 및 Silhouette 계수 측정 반복
for n_clusters in cluster_range:
    silhouette_scores_per_cluster_cosine = []
    silhouette_scores_per_cluster_euclidean = []
    
    for _ in range(10):  # 10번 반복하여 평균값 구함
        # Spectral Clustering 모델 생성 및 학습 (코사인 유사도 기반)
        clustering_model_cosine = SpectralClustering(n_clusters=n_clusters, affinity='cosine')
        cluster_labels_cosine = clustering_model_cosine.fit_predict(tfidf_matrix)

        # Spectral Clustering 모델 생성 및 학습 (유클리디안 거리 기반)
        clustering_model_euclidean = SpectralClustering(n_clusters=n_clusters, affinity='euclidean')
        cluster_labels_euclidean = clustering_model_euclidean.fit_predict(tfidf_matrix)

        # Silhouette 계수 측정 및 기록 (코사인 유사도)
        silhouette_avg_cosine = silhouette_score(tfidf_matrix, cluster_labels_cosine)
        silhouette_scores_per_cluster_cosine.append(silhouette_avg_cosine)
        
        # Silhouette 계수 측정 및 기록 (유클리디안 거리)
        distance_matrix_euclidean = pairwise_distances(tfidf_matrix.toarray(), metric='euclidean')
        silhouette_avg_euclidean = silhouette_score(distance_matrix_euclidean, cluster_labels_euclidean)
        silhouette_scores_per_cluster_euclidean.append(silhouette_avg_euclidean)

    # 각 클러스터 개수별로 Silhoutte 평균 값의 평균을 구함 (코사인 유사도)
    avg_silhouette_score_cosine= np.mean(silhouette_scores_per_cluster_cosine)
    silhouette_scores_cosine.append(avg_silhouette_score_cosine)

    # 각 클러스터 개수별로 Silhoutte 평균 값의 평균을 구함 (유클리디안 거리)  
    avg_silhoutte_score_eucildean= np.mean(silhoette_socres_per_cluster__eucildean )
   sillouette_socres__eucildean .append(avg_sihouette _score__eucildean )
    

# 클러스터 개수에 따른 Silhoutte 평균 값 시각화 (코사인 유사도)
plt.plot(cluster_range, silhouette_scores_cosine , marker='o', label='Cosin Similarity')
plt.xlabel('Number of Clusters')
plt.ylabel('Average Silhoutte Score')
plt.title('Silhoutte Score vs Number of Clusters - Cosin Similarity')

# 클러스터 개수에 따른 Sillouete Average 점 수 시각화(유클라이드 거리) 
plt.plot(cluster_range,sillouette_socres__eucildean , marker='o', label='Euclidian Distance ')
plt.xlabel('Number of Clusters')
plt.ylabel('Average Sillouete Score ')
plt.title('Sillouete Score vs Number of Clusters - Euclidian Distance ')

# 범례 추가 
plt.legend()

# 그래프 출력
plt.show()
