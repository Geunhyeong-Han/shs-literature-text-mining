# %% [markdown]
# ## Setting

# %% [markdown]
# ### Importing Dependencies

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\jjska\anaconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\jjska\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in c:\users\jjska\anaconda3\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\jjska\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\jjska\anaconda3\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: colorama in c:\users\jjska\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
import pandas as pd
import numpy as np

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_score
from sklearn.metrics.pairwise import cosine_similarity

from wordcloud import WordCloud

import matplotlib.pyplot as plt

# %%
nltk.download('stopwords')
nltk.download('wordnet')

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jjska\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\jjska\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ### Data Load & Cleaning

# %%
data = pd.read_csv("pilot_textming.csv")
data.head()
# Out:
#                                                Title  \
# 0  The development for Internet of Things smart h...
# 1  Service Provisioning Framework for Digital Sma...
# 2          SHSM: A Service Middleware for Smart Home
# 3  SDN-based multi-level framework for smart home...
# 4          Privacy-Aware Web Services in Smart Homes
#
#                                             Keywords  \
# 0                 IoT; smart home; service; platform
# 1  smart home; service provisioning; distributed ...
# 2  Smart Home; Service Middleware; Service Comput...
# 3  SDN; Smart home API; Smart services; Smart hom...
# 4    Policy; Privacy; Smart Home; Trust; Web service
#
#                                             Abstract
# 0  Internet of things smart home integrates autom...
# 1  Development and Management Framework of Smart ...
# 2  There emerges an increasing need to overcome t...
# 3  The smart home is a field that uses smart devi...
# 4  Smart homes can assist their inhabitants with ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Title     1000 non-null   object
#  1   Keywords  959 non-null    object
#  2   Abstract  999 non-null    object
# dtypes: object(3)
# memory usage: 23.6+ KB

# %%
data.dropna(subset=['Abstract'], inplace=True)
data.drop_duplicates(subset=['Title'], inplace=True)

# %%
data.shape
# Out:
# (998, 3)

# %%
def combine_2rd_columns(col_1, col_2, col_3):
    result = col_1
    if not pd.isna(col_2):
        result += " " + str(col_2)
    return result


data = pd.read_csv("pilot_textming.csv")
data["text"] = data.apply(lambda x: combine_2rd_columns(x['Title'], x['Keywords'], x['Abstract']), axis=1)

df = data.loc[:, ['text']]
df.tail()
# Out:
#                                                   text
# 995  Understanding Patient Activity Patterns in Sma...
# 996  Smart Home Security Cameras and Shifting Lines...
# 997  Multiobjective Optimization for Planning the S...
# 998  Voice Controlled Smart Mirror with Multifactor...
# 999   Leveraging Smart Meter Data & Expanding Services

# %% [markdown]
# #### Data Preprocess

# %%
def preprocess_text(text):
    # 소문자 변환 및 토큰화 (단어 단위로 분할)
    tokens = text.lower().split()
    
    # Stopword 제거 및 Lemmatization 수행
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens if token not in stop_words]
    
    # Stemming 수행 (Porter Stemmer 사용)
    stemmer = PorterStemmer()
    tokens = [stemmer.stem(token) for token in tokens]
    
    # 숫자 제거 및 재결합하여 문자열 반환
    processed_text = ' '.join([token for token in tokens if not token.isdigit()])
    
    return processed_text

df['processed_text'] = df['text'].apply(preprocess_text)
df = df.loc[:, ['processed_text']]
df.head()
# Out:
#                                       processed_text
# 0  develop internet thing smart home servic oper ...
# 1  servic provis framework digit smart home servi...
# 2  shsm: servic middlewar smart home smart home; ...
# 3  sdn-base multi-level framework smart home serv...
# 4  privacy-awar web servic smart home policy; pri...

# %%
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(df['processed_text'])
tfidf_matrix
# Out:
# <1000x2406 sparse matrix of type '<class 'numpy.float64'>'
# 	with 14430 stored elements in Compressed Sparse Row format>

# %% [markdown]
# #### Selected only the word-features - based on TF-IDF(Python scikit-Learn Library)

# %%
# 상위 Docuement 당 TF-IDF 기반 상위 4개의 단어 추출 함수 정의

top_keywords_per_document = []
feature_names = tfidf_vectorizer.get_feature_names_out()

for i in range(len(df)):
    tfidf_scores = zip(feature_names, tfidf_matrix[i].toarray()[0])
    sorted_tfidf_scores = sorted(tfidf_scores,key=lambda x: x[1], reverse=True)
    top_keywords_per_document.append([keyword for keyword,_ in sorted_tfidf_scores[:4]])

# 전체 데이터셋에서 적어도 2번 이상 나온 키워드 추출하기 
all_keywords=[keyword for document in top_keywords_per_document for keyword in document]
selected_keywords=list(set(keyword for keyword in all_keywords if all_keywords.count(keyword) >=2))

# 선택된 키워드를 기반으로 Document-Term Matrix 생성
vectorizer=CountVectorizer(vocabulary=selected_keywords)
document_term_matrix=vectorizer.fit_transform(df['processed_text'])

# WordCloud 시각화 함수 정의 및 실행   
def visualize_wordcloud(keywords):
     wordcloud=WordCloud(background_color='white', width=800,height=400).generate(' '.join(keywords))
     plt.imshow(wordcloud.recolor(colormap='viridis',random_state=42),interpolation="bilinear")
     plt.axis("off")
     plt.show()

visualize_wordcloud(selected_keywords)
document_term_matrix
# Out:
# <1000x655 sparse matrix of type '<class 'numpy.int64'>'
# 	with 11625 stored elements in Compressed Sparse Row format>

# %%
# # 재정규화된 TF-IDF 값으로 단어 분포 확인
# renormalized_tfidf_matrix = tfidf_matrix / tfidf_matrix.sum(axis=1)
# word_distribution_per_document = renormalized_tfidf_matrix.A # .A to convert sparse matrix to numpy array

# print("Word Distribution per Document:")
# for i in range(len(df)):
#     print(f"Document {i+1}:")
    
# word_distribution_pairs = zip(feature_names, word_distribution_per_document[i])
# sorted_word_distribution_pairs = sorted(word_distribution_pairs,key=lambda x: x[1], reverse=True)

# for word,distribution in sorted_word_distribution_pairs:
#         print(f"{word}: {distribution}")

# %% [markdown]
# #### Gaussian mixture model (GMM) Elimniated Type 1 & Type 2

# %%
# 키워드들의 TF-IDF 벡터를 가져옵니다.
selected_keywords_list = list(selected_keywords)
selected_keyword_indices = [np.where(feature_names == keyword)[0][0] for keyword in selected_keywords_list]
selected_tfidf_vectors = tfidf_matrix[:, selected_keyword_indices].toarray()

# GMM 클러스터링을 수행합니다. 
n_clusters = 100 # 임의로 설정한 클러스터 개수
gmm = GaussianMixture(n_components=n_clusters)
gmm.fit(selected_tfidf_vectors)

# 각 클러스터에 속하는 단어들의 리스트를 생성합니다.
clusters = [[] for _ in range(n_clusters)]
labels = gmm.predict(selected_tfidf_vectors)
for word, label in zip(selected_keywords_list, labels):
    clusters[label].append(word)

# 10번의 클러스터링 분석을 수행하고, 일관되게 중요하지 않다고 판단되는 단어들을 추출합니다.
non_important_words_sets = []
for _ in range(10):
    gmm.fit(selected_tfidf_vectors)
    labels = gmm.predict(selected_tfidf_vectors)
    
    # 가장 큰 클러스터를 '중요하지 않은' 단어들로 간주합니다.
    largest_cluster_label = np.bincount(labels).argmax()
    non_important_words_sets.append(set(word for i, word in enumerate(selected_keywords_list) if labels[i] != largest_cluster_label))

# 모든 실행에서 공통적으로 중요하지 않다고 판단된 단어들만 추출합니다.
common_non_important_words_set = set.intersection(*non_important_words_sets)

print("Common Non-Important Words:")
for word in common_non_important_words_set:
    print(word)

# 선택된 키워드 목록에서 공통적으로 중요하지 않은 단어들을 제거합니다.
final_selected_keywords_set = set(selected_keywords_list) - common_non_important_words_set

print("\nFinal Selected Keywords:")
for word in final_selected_keywords_set:
    print(word)
# Out:
# Common Non-Important Words:
# appliance
# creat
# city
# need
# novel
# graph
# socket
# consist
# univers
# test
# correl
# deploy
# project
# privat
# languag
# systemat
# social
# continu
# scenarios
# autonomy
# resili
# manag
# composition
# queu
# cent
# disabilities
# finger
# agreement
# 15
# network
# password
# alexa
# studi
# peopl
# healthi
# support
# pervas
# cot
# realiz
# bridg
# intellig
# track
# sensing
# motion
# telemedicine
# acceptance
# gener
# osgi
# remote
# cloud
# alloc
# semant
# gateway
# wsn
# disabl
# domest
# fi
# driven
# identity
# link
# offer
# review
# relat
# interoper
# lab
# recent
# fault
# qo
# domot
# realist
# code
# devic
# function
# proxi
# age
# ict
# decentr
# pilot
# th
# intelligence
# literatur
# upnp
# new
# cognit
# healthcare
# author
# consumpt
# physic
# play
# model
# transfer
# microgrid
# dpws
# centric
# domain
# memori
# recommend
# secur
# ui
# event
# non
# ethics
# analytics
# emergency
# decis
# care
# reinforc
# linear
# activ
# open
# group
# satisfact
# uncertainti
# human
# universa
# meter
# virtual
# korea
# among
# patient
# neural
# cybersecurity
# interview
# services
# implementation
# she
# chines
# enrich
# context
# plug
# applic
# qos
# centr
# analysi
# development
# population
# wi
# flow
# spatial
# buildings
# schedul
# daili
# ai
# futur
# object
# authent
# collaboration
# mental
# analyt
# system
# isp
# place
# one
# comfort
# cbr
# ecosystem
# rfid
# product
# iot
# theoret
# messag
# conflict
# interior
# technolog
# action
# select
# synthet
# universaal
# controller
# approach
# wast
# phone
# tim
# connect
# frequenc
# scheduling
# detection
# acquisition
# zone
# denial
# problem
# reasoning
# key
# optim
# theori
# programming
# arm
# understand
# protocol
# communications
# build
# community
# ontologies
# software
# line
# within
# nurs
# work
# investig
# proof
# learn
# healthcar
# develop
# aware
# mean
# qualiti
# concept
# privaci
# plan
# light
# internet
# area
# accept
# sensors
# co
# elder
# hierarch
# smart
# comput
# embed
# busi
# barrier
# reconfigur
# video
# energi
# authentication
# fabric
# case
# web
# arduino
# propos
# rest
# service
# hyperledg
# speaker
# program
# lite
# benefit
# independ
# rssi
# pension
# edg
# reason
# surveil
# traffic
# access
# big
# modular
#
# Final Selected Keywords:
# hbbtv
# europ
# media
# indoor
# interoperability
# orchestr
# rout
# improv
# compon
# privacy
# grids
# qoe
# cyber
# machin
# sensit
# toward
# inform
# car
# soap
# electr
# retriev
# robots
# environments
# networks
# screen
# anomali
# eca
# intent
# grid
# provis
# depth
# prediction
# interfac
# multipl
# zero
# echonet
# amr
# encrypt
# softwar
# heterogen
# sens
# profil
# present
# resid
# counter
# algorithm
# ontolog
# fine
# constraint
# 802
# profile
# infrar
# self
# perceiv
# models
# homes
# pi
# wireless
# senior
# to
# lightweight
# ecolog
# sensori
# us
# mathemat
# perspect
# knowledge
# adapt
# transport
# util
# commun
# multimedia
# popul
# data
# prototyp
# woo
# ethic
# progress
# china
# ubiquit
# hous
# paradox
# appliances
# cross
# methodolog
# in
# dynam
# vision
# upload
# end
# overview
# classification
# personalization
# natur
# architecture
# forensics
# beacon
# knowledg
# multi
# bandwidth
# enhanc
# anonymity
# feedback
# gesture
# contract
# base
# life
# provid
# sign
# on
# robotics
# posit
# auto
# oper
# driver
# 5g
# attribut
# metering
# design
# architectur
# digit
# public
# home
# accur
# tv
# risk
# cluster
# recognit
# markov
# agent
# ad
# coordin
# ethereum
# awar
# train
# rf
# person
# recognition
# networking
# security
# telehealth
# process
# safeti
# complex
# advanc
# consortium
# scenario
# time
# survey
# threat
# critic
# protect
# local
# via
# thing
# side
# signatur
# aging
# modelling
# small
# ident
# blockchain
# artifici
# broadcast
# analyz
# efficiency
# interact
# assist
# concurr
# voice
# component
# infrastructur
# conceptu
# mirror
# sid
# machine
# activity
# nfv
# demand
# joint
# aspect
# experi
# switch
# set
# applianc
# multiag
# monitoring
# sensor
# pattern
# class
# forecasting
# level
# scheme
# conveni
# sdn
# foresight
# emerg
# behavior
# storag
# use
# ecosystems
# framework
# assess
# agenda
# mechan
# radar
# platform
# ddos
# method
# value
# systems
# grain
# concern
# localization
# solut
# deep
# integration
# environ
# issu
# eco
# avail
# ubiquitous
# health
# meters
# technology
# things
# chronic
# aggregation
# defens
# of
# middleware
# mainstream
# cities
# channel
# name
# emot
# trust
# layer
# binari
# ori
# resource
# space
# allocation
# gerontechnolog
# ccbr
# ecdh
# adoption
# control
# view
# ambient
# optimization
# tracking
# location
# zigbee
# remot
# real
# mode
# management
# fuzzi
# residenti
# device
# pufs
# usag
# integr
# cybersecur
# task
# research
# imag
# configur
# societi
# ontology
# soa
# citi
# next
# deliv
# interface
# percept
# preserv
# trilateration
# discoveri
# semantics
# innovation
# discovery
# residences
# detect
# friendli
# domotics
# guidanc
# live
# application
# medium
# consid
# bas
# simpl
# price
# priority
# opportun
# hem
# attack
# industri
# monitor
# caregiv
# practic
# appli
# comprehens
# rule
# bodi
# resolut
# featur
# inhabit
# agents
# ddo
# intrus
# mine
# user
# implement
# abnorm
# analysis
# science
# wifi
# simul
# polici
# readi
# computing
# associ
# power
# biophil
# automat
# learning
# topolog
# app
# adopt
# older
# infer
# consum
# challeng
# tool
# awareness
# exchang
# green
# predict
# passiv
# net
# 6lowpan
# composit
# affect
# automation
# intention
# hom
# establish
# medic
# aal
# depend
# mobil
# provisioning
# fog
# study
# nonintrus
# response
# autonom
# map
# cost
# servic
# formal
# tensorflow
# zigbe
# refer
# robot
# character
# enocean
# gsm
# technologies
# behaviour
# autom
# effici
# api
# ieee
# m2m
# hybrid
# tree
# protection
# renew
# load
# pet
# consumer
# middlewar
# abstract
# bluetooth
# valu
# onlin
# voic
# convers
# elderly
# requir
# distribut
# defin
# elderli
# challenges
# consumption
# well
# resourc
# ip
# occup
# locat
# led
# energy
# low

# %%
print(len(final_selected_keywords_set))
# Out:
# 407

# %%
# Document-Term Matrix에서 각 키워드별로 평균 TF-IDF 값을 계산합니다.
vectorizer = TfidfVectorizer(vocabulary=final_selected_keywords_set)

tfidf_matrix = vectorizer.fit_transform(df['processed_text'])  # 'documents'는 문서 리스트입니다.

avg_tfidf_values = tfidf_matrix.mean(axis=0).A1  # 'A1'은 numpy array를 1차원으로 변환합니다.

keyword_tfidf_dict = dict(zip(vectorizer.get_feature_names_out(), avg_tfidf_values))

for word, value in keyword_tfidf_dict.items():
    if np.isnan(value):
        print(f"'{word}' has a TF-IDF value of NaN.")
        keyword_tfidf_dict[word] = 0
        
# 워드 클라우스 객체 생성
wordcloud = WordCloud(width=800, height=400, background_color='white')

# 선택된 키워트들과 그들의 평균 TF-IDF 값으로부터 워드클라우스 이미지 생성
wordcloud.generate_from_frequencies(frequencies=keyword_tfidf_dict)

# 워듣클라우스 시각화
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# #### Eliminated outliers by calculating the cosine similarities

# %%
# 1. TF-IDF 값을 다시 계산합니다.
vectorizer = TfidfVectorizer(vocabulary=final_selected_keywords_set)
tfidf_matrix = vectorizer.fit_transform(df["processed_text"])

# 2. 각 데이터 항목(문서) 간의 코사인 유사도를 계산합니다.
cosine_sim_matrix = cosine_similarity(tfidf_matrix)

# 3. 코사인 유사도가 특정 임곗값보다 높은(즉, 문서들이 매우 비슷한) 데이터 항목들을 제거합니다.
threshold = 0.8  # 임곗값 설정
outlier_indices = []

for i in range(len(df)):
    for j in range(i+1, len(df)):
        if cosine_sim_matrix[i][j] > threshold:
            outlier_indices.append(j)

# 중복된 인덱스 제거
outlier_indices = list(set(outlier_indices))

# 이상치 아닌 문서만 선택하여 최종 문서 집합 생성
final_documents = [doc for i, doc in enumerate(df["processed_text"]) if i not in outlier_indices]

# %%
final_documents
# Out:
# ['develop internet thing smart home servic oper support platform iot; smart home; service; platform',
#  'servic provis framework digit smart home servic smart home; servic provisioning; distribut system',
#  'shsm: servic middlewar smart home smart home; servic middleware; servic computing; intellig home space',
#  'sdn-base multi-level framework smart home servic sdn; smart home api; smart services; smart home framework',
#  'privacy-awar web servic smart home policy; privacy; smart home; trust; web servic',
#  'smart citi servic platform associ smart home smart citi servic platform; smart home; internet thing(iot); context inform',
#  'smart home product-servic systems: two focal area develop competit smart home applianc smart home; smart home applianc (sha); product-servic system (pss)',
#  'propos integr smart home servic platform internet things; smart home; smart servic',
#  "framework smart-hom servic elderly' biophil experi elderly; biophilia; biophil experience; smart home; smart-hom service; servic framework",
#  'research smart home servic platform base mobil cloud smart home; servic platform; mobil cloud; integr servic applic',
#  'middlewar iot-bas smart home base servic iot; smart home; middleware; soa',
#  'integr commun servic platform system link smart home smart citi internet thing(iot); integr commun service; smart city; smart home; context inform',
#  'develop middlewar architectur realiz context-awar servic smart home environ context-aware; middleware; ontology; profile; reasoning; service; smart home',
#  'secur web servic home autom smart grid environ security; smart homes; web services; smart grid',
#  'smart home servic next mainstream ict industry: determin adopt smart home servic smart home services; technolog accept model; compatibility; perceiv connected',
#  'analysi type import sensor smart home servic smart home service; sensor importance; analysi sensor types; internet thing',
#  'iot servic framework smart home: case studi hem smart home; servic framework; lab things; mqtt; azur',
#  'use web servic medic manag smart home environ smart home; web services; osgi; medic',
#  'upnp remot ui sensor collabor framework cloud av servic smart home smart home; home networking; cloud computing; upnp; upnp remot ui',
#  'middlewar aid context-awar servic smart home smart home; context-aware; cooperative; ontology; servic',
#  'risk driven smart home resourc manag use cloud servic internet things; smart home; risk; web servic',
#  'smart home assist live addit servic offer user smart home; assist livingt; addit servic',
#  'smart home servic enabl servic level agreement smart home; coordination; services; servic level agreements; slas; map perceiv paramet - physic parameters; monitoring; multi agent system',
#  'privacy-awar sensor data upload manag secur receiv smart home servic smart home; privacy; risk; benefit; optim',
#  'reinforc learn base architectur dynam gener smart home servic servic orientation; reinforc learning; multi-agent; smart home',
#  'web servic gsm base smart home control system smart home; gsm; zigbee; web services; embed server; graphic user interface<bold>; </bold>',
#  'smart home servic demonstration: monitoring, control secur servic offer user smart home networks; smart district; energi consumption; comfort safeti servic',
#  'design smart home system base servic encapsul devic abstract smart home; devic abstract; servic encapsulation; upnp',
#  'build smart home system wsn servic robot smart home; wireless sensor networks; servic robot',
#  'smart home servic base event match event matching; infer engine; rete algorithm; complex event; smart home',
#  'impact iot smart home servic psycholog well-b iot; smart home services; well-being; hedon motivation; eudaimon motiv',
#  'bridg structur devic social framework smart home servic devic sociality; devic collaboration; devic interaction; smart home servic',
#  'adapt smart home servic base smart contract servic level agreement domain&#8208; specif language; elderli person; microservice; service&#8208; level agreement; smaf; smart contract; smart home',
#  'machin learning-bas non-intrus digit forens servic smart home digit forensics; secur service; internet things; smart home; machin learn',
#  'prefer usabl smart-hom servic items-a focu smart-hom living-lab - smart-home; living-lab; smart item; preference; usabl',
#  "smartgreeting: new smart home system enabl context-awar servic persons' counting; person services; smart home; passiv infrar sensor",
#  'smart door: ubiquit collabor system home activ smart home smart home; home collaboration; home activity; ubiquit service; home calendar; home portal',
#  'formal model robust spatial-awar servic manag iot-enrich smart home smart home; ambient; soa; servic manag',
#  'empir examin intent continu use smart home servic smart home; servic quality; perceiv usefulness; satisfaction; habit; continu intent',
#  'ecdh-bas 3pake protocol secur smart home servic smart home; password-bas authentication; 3pake',
#  'non-repudi scheme smart home base cloud servic cloud service; smart home; non-repudiation; digit signature; bilinear pare',
#  'product servic - strategi upscal smart home perform monitor build perform monitoring; hous quality; home improvement; net-zero home (nzh); product-as-service; smart home technolog',
#  'interoper framework smart home system interoperability; smart home; soap; web servic',
#  'time base markov model automat position-depend servic smart home markov model; locat awareness; automat service; smart home',
#  'secur qos-awar commun smart home servic congest control; ethernet; security; smart home',
#  'context-awar multimedia servic schedul framework smart home context-aware; servic scheduling; multimedia prompting; smart home',
#  'enrich smart home servic integr social network servic big data analyt smart home; big data analytics; ambient intelligence; social networks; social network servic',
#  'flexibl potenti smart home provid tso-dso-level servic smart homes; flexibl services; energi flexibility; demand response; control applianc',
#  'smart home architectur base resourc name servic smart home; internet things; identifier; rns; interoperability; compat',
#  'hybrid-awar model senior well servic smart home context-aware; inspect servic middleware; smart home',
#  'smart home integr extern iot devic platform servic smart homes; cameras; meteorology; cloud computing; smart cities; consum electronics; cloud',
#  'woo base emerg servic support function smart home care woo; web objects; support function; emerg service; smart home care',
#  'integr servic robot smart home mean upnp: surveil robot case studi servic robots; interoperability; smart home',
#  'intercloud commun value-ad smart home smart grid servic smart home; smart grid; intercloud comput',
#  "servic platform ecosystem smart home 2.0 era: element influenc consumers' valu percept smart home product platform ecosystem; smart home; iot service; modularity; inter-consum connectivity; valu percept",
#  'energi consumpt inform servic smart home inhabit energi awareness; smart home; social networks; energi efficiency; visualization; user interfac',
#  'ethereum-bas emerg servic smart home system: smart contract implement internet thing (iot); smart home; emergency; ethereum; privat blockchain; smart contract; solidity; ipfs; pki; one time passcod',
#  "preference-driven smart home servic elderly' biophil experi smart home service; elderli population; mental health; biophil experience; smart technolog",
#  'energi effici sensor network servic discoveri smart home environ wireless sensor network; servic discovery; smart home; tinyos; intellig space',
#  'health smart home servic incorpor mar-bas energi consumpt awar system energi consumpt awareness; health smart home service; mobil augment reality; energy-rel behavior',
#  'enabl smart behavior automat servic composit internet things-bas smart home internet things; automat servic composition; smart homes; servic semantics; virtual network',
#  'dynam conflict resolut iot servic smart home iot service; multi-resid smart home; prefer extraction; prefer aggregation; conflict resolut',
#  'studi adopt iot smart home service: use value-bas adopt model iot; smart home service; value-bas adopt model',
#  'deliv analyt servic smart home internet things; smart home; home automation; data analytics; usag prediction; recommend system',
#  'precis passiv rfid local servic deliveri smart home smart home; activ recognition; servic delivery; localization; passiv rfid; trilateration; fuzzi logic.',
#  'implement smart home servic web object architectur smart home; internet things; web object; servic platform',
#  'design u-healthcar servic system base person model smart home personalization; u-healthcare; ubiquitous; smart home',
#  'ecolog view smart home technolog smart objects; smart home; ecolog view; domotics; intellig home services; human comput interaction; ambient intellig',
#  'smart home technologies: preliminari review smart home; home automation; sensor technolog',
#  'energi optim energi manag home via web servic smart grid dynam programming; optimization; energi management; smart grids; smart homes; web services; wireless sensor network; zigbe',
#  'smart home smart citi solut enabl 5g, iot, aai cot servic 5g; smart cities; smart homes; internet things; artifici intelligence; big-data',
#  'caregiv develop activity-support servic smart home smart home; ambient assist living; assist computing; end-us program',
#  'user accept smart home services: extens theori plan behavior interoperability; mobility; theori plan behaviour; automation; security/privaci risk; smart home servic',
#  'data-flow program smart home smart space visual program languages; data-flow programming; smart homes; smart spaces; smart servic',
#  'develop led smart switch light-weight middlewar location-awar servic smart home smart switch; location-awar service; light-weight middleware; distribut scheme',
#  'fault diagnosi method smart home servic smart home system; fault diagnosis; causal graph; symptom-problem correl model; featur symptom',
#  'risk assess home gateway/smart meter smart grid servic smart grid; home gateway; smart meter; risk assess',
#  'ontolog interoperability: model composit servic smart home environ composit services; interoperability; ontology; smart home',
#  'self-evolv ontology-bas servic person framework disabl user smart home environ component; person service; ontology; ontolog evolution; disabl user; home applianc',
#  'framework cloud-bas smart home smart home; cloud computing; cloud services; intellig control',
#  'iot smart home concept home automatization; internet thing (iot); smart home; smart hous',
#  'ecolog approach smart home health care services: conceptu framework smart servicescap wheel health care inform management; system analysis; smart home health care services; ecolog approach; conceptu framework; smart servicescap wheel',
#  'ontology-bas home servic model smart home; home service; domain ontology; need; function',
#  'support smart home systems: util assess internet servic provid network smart home system network traffic; smart home systems; smart home system network activ',
#  'rest design implement smart applianc smart home smart home; smart appliance; rest architectur',
#  'evalu smart home servic items: live lab user experi studi smart home; user evaluation; smart technology; smart item; ipa analysis; factor analysi',
#  'smart mat part wireless sensor network system smart home servic smart home; wireless sensor network; smart textile; footprint recognition; ambient intelligence; zigbee; ad hoc network',
#  'woo base pet-car servic smart home iot; web objects; smart home; pet-car',
#  'semant approach decis support safeti servic smart home manag smart homes; decision; safeti servic',
#  'design intellig home pension servic platform base machin learn wireless sensor network machin learning; wireless sensor; smart home; pension servic',
#  'rule-bas servic custom strategi smart home context-awar autom smart home; context-awar automation; decis support; servic customization; rule gener',
#  'conflict detect framework iot servic multi-resid smart home iot services; multi-resid smart home; conflict ontology; formal conflict model; conflict detect',
#  "analyz elderli users' adopt smart-hom servic behavior intention; elderly; qualiti life; smart-hom",
#  'intellig self-adjust sensor smart home servic base zigbe commun wireless sensor network; smart home service; home energi manag system; topolog control; self-adjust',
#  'conflict detect iot-bas smart home internet things; iot service; smart home; conflict detection; knowledg graph',
#  'smart home: consum craft new servic network combin heterogen smart domest product smart home; internet things; craft consumers; big data; servic design',
#  'context-awar authent servic smart home internet things; security; context-awar authentication; smart home; access control',
#  'establish common servic platform smart living: challeng research agenda smart homes; servic platform; servic innovation; locat base servic',
#  'relat review smart meter smart home smart grid applic smart metering; smart meters; smart home; smart grids; devic smart control; energi smart management; sensor network',
#  'sdif: social devic interact framework encount play smart home servic devic sociality; devic collaboration; devic encounter; smart home servic',
#  'knowledge-bas auto-configur system use ubiquit robot servic deliveri smart home smart home; ubiquit robotics; servic delivery; semant web; knowledge-bas auto-configur system',
#  'artifici intellig system multimedia servic smart home environ deep learning; classification; smart home; reinforc learning; multimedia',
#  'smart home: integr internet thing web servic cloud comput smart home; internet things; cloud computing; arduino; zigbee; json',
#  'predict consum intent toward eco-friendli smart home services: extend theori plan behavior theori plan behavior; environment knowledge; ambigu tolerance; compatibility; live habits; eco-friendli smart home servic',
#  'explor cognit process servic task smart home: robot servic mechan smart home; robot servic mechanism; system cooperation; knowledg representation; cognit process; activ servic',
#  'function semant home servic smart home; service; function concept ontolog',
#  'service-bas interact proxi sensor network smart home group proxy; domain proxy; smart space',
#  'resource-awar smart home manag system construct resourc relat graph home resourc model; smart home resourc management; resourc relat graph',
#  'household designers? gener futur energi servic unit kingdom home occupi co-design; servic design; energy; smart homes; smart data; energi servic',
#  'smart home (conceptu views) smart home; intellig home; autom home; internet things; iot; projects; ambient intellig',
#  'associ benefit barrier perceiv user smart home servic implement servic technology; user; internet things; intellig home',
#  "possibl barrier consumers' adopt smart home services? smart home; internet things; barriers; resistance; perceiv risk; uncertainti",
#  'futur chang smart home base aal healthcar servic ambient assist living; smart home; healthcare; iot; residenti environ',
#  'develop evalu smart contract-en blockchain system home care servic innovation: mix method studi home care service; trust; innovation; blockchain; smart contract; autom',
#  'cyber-en human-centr smart home architectur smart home; human-centric; architecture; iot; cyber; social; thinking; smart city; smart world',
#  'semant servic registr retriev smart home home service; servic retrieval; domain ontolog',
#  'home energi manag system energy-effici smart home efficiency; energy; smart grid; smart home; smart plug',
#  'develop design solut smart home user-cent scenario smart home; user-cent scenario; design solution; framework smart home service; context',
#  'rosa: resource-ori servic manag scheme web thing smart home iot; web things; rest; web services; univers plug play (upnp); smart home',
#  'smart home users? analysi adopt diffus smart home consum behavior; multivari probit model; network externality; smart home; technolog accept model',
#  'research smart home-car servic system chengdu commun base internet plu smart home care; internet; care system; user demand',
#  'hic: interact ubiquit home control system smart home home controller; smart home; interact projection; ambient assist live',
#  'sdn base qo awar bandwidth manag framework isp smart home softwar defin network (sdn); qualiti servic (qos); smart home; bandwidth manag',
#  'smart home defens ddo attack ddos; iot; notifications; smart home',
#  'hardwar environment-agnost smart home architectur container on-the-fli servic offload internet things; fog computing; smart homes; home autom architecture; docker; servic orchestration; real-tim servic deploy',
#  'context agent smart home resid context; agent; smart home; 5w1h',
#  'laboratori smart home energi manag system home energi manag system (hem); smart home; smart grid',
#  'ant-bas servic select framework smart home monitor environ smart environment; ambient medium service; ant base selection; servic composit',
#  'semant servic gateway echonet base smart home echonet lite; semant servic gateway; universa',
#  'gesture-bas smart home-ori health monitor servic peopl physic impair smart home; gestur base interaction; natur user interfaces; remot health monitor',
#  'critic review user studi healthi smart home user study; healthi smart home; smart service; smart technology; evalu method',
#  'toward resili smart home iot security; smart home resiliency; smart home secur',
#  'home applianc control framework base smart tv set-top box home applianc control; smart home service; smart tv; set-top box',
#  'foge energi optim smart home fog; smart homes; load balancing; servic broker policy; round robin; honey bee',
#  'elabor synthet data gener internet thing servic smart home environ iot; smart home; data analysis; synthet data gener',
#  'propos context-awar smart home ecosystem smart home; ecosystem; context-awareness; smart scenario; context modeling; context reasoning; architectur smart homes; web service; soa; pervas comput',
#  'integr cloud-bas smart home manag system commun hierarchi smart home manag system; commun broker; cloud services; mqtt',
#  'post-quantum blockchain secur commun iot-bas smart home servic internet things; iot; blockchain; smart home; post-quantum cryptographi',
#  'coordin web servic smart home design; experimentation; human factors; service-ori architecture; servic composition; internet thing',
#  'implement evalu user-cent requir smart in-hous mobil servic smart home technology; smart mobil services; user need',
#  'design evalu virtual home object music interact smart home smart home; virtual home object; rfid; human-comput interact',
#  'smart home platform support decentr adapt autom control smart home platforms; softwar architectur style smart home systems; architecture-bas self-adaptation; mape-k; openhab',
#  'pbre: rule extract method train neural network design smart home servic rule extraction; neural network; reinforc learning; smart home',
#  'connect smart home matter protocol smart home; iot; matter protocol; connect home; ipv6',
#  'system architectur smart home meter smart homes; smart meters; system architecture; aw iot platform',
#  'enhanc secur framework home applianc smart home smart device; self-sign system; data integrity; home appliance; access control',
#  'methodolog interoper inform manag smart home environ inform management; devic interoperability; smart home system design; servic design; product-servic system',
#  'web object base energi effici smart home iot servic provis internet things; web objects; virtualization; energi efficiency; smart home',
#  'smart home adoption: impact user characterist differ percept benefit smart home; technolog adoption; servic preference; user characteristics; influenc factor',
#  'semant inform manag user context awar smart home social servic context-awareness; inform management; smart home',
#  'smart grid multi-util servic platform base power fiber home smart grid; oplc; pftth; multi-utility; servic platform; smart power consumpt',
#  'toward intellig servic smart home environ',
#  'distribut effici system architectur smart home iot; internet things; smart home; distribut system; soa; service-ori architecture; osgi; open servic gateway initi',
#  'infrastructur intellig autom servic smart grid home area network; smart energi profile; intellig autom services; smart grid',
#  'wireless sensor network smart home servic use optim commun smart homes; wireless sensor networks; energi consumpt pattern; stream services; channel util',
#  'iot devic manag framework smart home scenario devic management; iot; smart home',
#  'healthi age support smart home technolog smart homes; smart technology; sensors; elderly; internet thing',
#  'energi manag servic base home energi grid technolog smart; energi saving; smart grid; home; smart plug',
#  'data-driven futurist scenarios: smart home servic experi foresight base social medium data futur scenarios; data-driven; futur triangle; servic experience; smart home; futur think',
#  'research perform optim applic smart home hyperledg fabric secur smart homes; access control smart homes; secur control smart homes; blockchain; fabric',
#  'sensor technolog smart home smart homes; sensor technology; independ living; aging; disabl',
#  'social barrier adopt smart home public perceptions; smart homes; social barrier',
#  'co-liv rental home experience: smart home technolog autonomi co-living; smart home technologies; autonomy; smart hous',
#  'work progress: smart home energi (she) energet efficiency; digit home; web services; smart system',
#  'assess smart home: secur privaci iot; security; smart home system; home automation; data exchang',
#  'integr digit home, smart applianc servic robot use dhcompliant 2.0 dhcompliant; dwps; digit home; interoperability; servic robot',
#  'upcom servic innov home energi manag system korea home energi manag system; smart home; servic innovation; service-domin logic; sustain busi model',
#  'intellig smart home energi effici model use artifici tensorflow engin smart home; iot platform; integr oper system; intellig models; awareness; energi efficiency; service; learning; autom',
#  'web-bas smart home automation: plc-control implement home automation; plc; remot control; smart home',
#  'smart home technolog acceptance: empir investig technolog accept model; smart home technology; smart technology; use behaviour',
#  'toward uninterrupt smart home process decentr process execution; smart home process; heterogen workflow enact service; decentr process manag system; busi process manag system; bpms; smart home',
#  'robot smart home: project toward interoper smart home; middleware; interoperability; servic robots; upnp; univers plug play; roomba',
#  'situation-theoret analysi human intent smart home environ context-awareness; evolution; goal; human intention; requirements; service; situat theory; smart home',
#  'rish: robot-integr smart home elderli care elderli care; smart home; home servic robot; assist technolog',
#  'multi-occup movement track smart home environ tracking; activ recognition; smart home',
#  'smart home implement base internet wifi technolog smart home; home automation; remot control; iot; internet; wifi',
#  'cyber secur challeng smart home smart homes; threat vectors; medic devices; interconnectedness; model',
#  'develop smart home market uk smart home; driver; barrier; public workshop; expert interview',
#  'robot interact domest environ consid aal servic smart home technolog mobil robotics; home automation; ambient assist live',
#  'advanc secur data protect smart home system blockchain technolog smart home; iot; blockchain; services; security; hyperledg',
#  'new layer architectur futur big data-driven smart home big data management; internet things; smart home; layer architecture; data-driven servic',
#  'survey assess privaci concern smart-hom servic provid individu disabl disabilities; privacy; smart homes; telecare; technolog',
#  'context awar approach smart home context-aware; cbr; smart homes; ccbr; ubiquiti comput',
#  'toward task support system cbr approach smart home context; task; cbr; similarity; smart home',
#  'ubiquit rest smart home energi manag system smart home; web things; energi management; sensor network',
#  'survey predict algorithm smart home intellig systems; internet things; predict methods; smart home',
#  'smart home elderli care: develop challeng china smart home; elderli care; china',
#  'iss: interact smart home simul smart home simulator; ubiquit computing; context awar',
#  'iot base smart home : secur aspect secur architectur iot; smart home; smart home architecture; iot secur',
#  'resource-ori architectur smart home oper manag platform keyword smart environments; smart home; cwmp; oper management; resource-ori architecture; rest',
#  'lightweight encrypt smart home smart home; internet things; security; identity-bas encryption; lightweight encryption; iot',
#  'privaci secur challeng smart connect home smart home; security; privacy; iot',
#  'secur authent approach smart termin edg servic smart home; authent session key negotiation; ellipt curv code; edg servic',
#  'servic pattern-ori smart bedroom base elderli spatial behaviour pattern servic pattern; smart home; elderli behaviour; smart bedroom; spatial behaviour pattern',
#  'home-to-hom commun smart commun internet thing internet things; wireless sensor network; smart community; smart home; local collabor',
#  'certif base authent scheme smart home ecc; mutual authentication; privacy; smart home; secur',
#  'context awar systems, method trend smart home technolog context-awar computing; smart home; ubiquitous; autom',
#  'smart home base wifi sensing: survey iot; smart home; wifi sens',
#  'model-driven develop approach provid smart home servic',
#  'web servic indoor energi manag smart grid environ demand response; indoor communication; smart grids; smart homes; web services; wireless sensor networks; zigbe',
#  'perform evalu smart coap gateway remot home safeti servic home satety; coap; gateway; border router; wireless connect',
#  'issu appli instant messag smart home system instant messaging; smart home; applianc collabor',
#  'factor influenc smart age care servic accept elderli nurs homes: perspect perceiv qualiti smart age care services; nurs home; acceptance; percept qualiti',
#  'context-awar smart home control system base zigbe sensor network zigbee; ieee 802.11x; wlan; smart home',
#  'iot-bas led light control smart home light control; home automation; smart home; cloud service; internet thing (iot)',
#  "social issu smart home: review four european cities' experi smart city; smart home; smart home technolog services; social barrier",
#  'find misplac item use mobil robot smart home environ home servic robot; smart home; heterogen sensors; autonom robot retrieval; tp242;',
#  'reseach architectur smart home network servic platform',
#  'latenc analysi wireless network proxim servic smart home build automation: case thread proxim service; smart home; build automation; internet things; ieee 802.15.4; latency; thread; wireless sensor network',
#  'review smart homes-past, present, futur healthcare; home automation; pervas computing; smart homes; telemedicine; ubiquit comput',
#  'side channel attack smart home systems: short overview smart home; privacy; side-channel attack',
#  'agent-bas smart home system service-schedul mechanism: design implement ab home system; agent platform; univers plug play (upnp); service-schedul mechan',
#  'secur evalu method smart home cloud platform artifici intelligence; smart home; cloud platform; secur evalu',
#  'base cube one: location-address service-ori smart environ framework smart environment; smart home; architecture; location-based; servic orient architecture; soa; servic discovery; hardwar abstract layer; base cube one; bco; cognit servic robot apartment; csra',
#  'defin concept smart nurs home potenti technolog util integr medic servic accept stakeholders: scope review smart nurs homes; smart technologies; integr medic services; qualiti care; accept stakehold',
#  "exploratori studi consumer' need smart home korea smart home; home iot; korean case study; consum need",
#  'concurr traffic queu game smart home concurr traffic; qualiti service; smart home; traffic schedul optim',
#  'provid new energi manag approach smart home use 6lowpan protocol smart home; smart home area networks; smart energi manag system; 6lowpan protocol',
#  'dynam qos-awar queu heterogen traffic smart home smart home; qualiti service; traffic schedul optim',
#  'studi architectur smart home manag system key devic smart home; architecture; smart home gateway; smart jack; wsn; zigbee; wi-fi; dali',
#  'smart home base patronag solut internet things; smart home healthcar application; user behavior analysi simul',
#  'flexibl manag smart home compon framework; home automation; goal refinement; open servic gateway initiative; policy-bas management; sensor network; telecar',
#  "scenario-bas smart servic single-person household single-person households; singl person' behaviour; singl person' needs; scenario-bas services; smart homes; smart servic",
#  'learn smart home data: method challeng data acquisit analysi smart home solut smart homes; data mining; temperatur sensors; heat systems; machin learning; home autom',
#  'explor sustain valu smart home strengthen adopt smart home; technolog adoption; user-cent design; user percept',
#  "intervent non-inhabit activ detect smart home environ activ recognition; multipl inhabitant; allen' tempor logic; smart home",
#  'seamless multimedia servic mechan base content profil use user devic id person mobil smart home multimedia; smart home; person mobility; multi-device; multi-loc',
#  'activ recognit smart home smart homes; activ recognition; latent features; bp-hmm',
#  'smart home energi manag system internet thing network green citi demand servic smart home energi management; smart thermostat; smart home; thermal comfort control; smart energi control; smart home energi manag system opportun',
#  'secur visibl light encrypt commun techniqu smart home servic smart home service; visibl light communication; rsa encryption; key length; perform enhanc',
#  "critic review smart home technolog applic busi model europ smart home technologies; smart energy; 'prosum '; decarbonis",
#  'fog-bas smart homes: systemat review fog computing; smart homes; smart buildings; systemat review; internet thing (iot)',
#  'smart home iot application: predict attitud behaviour internet things; user acceptance; smart home attributes; smart home; technolog accept model',
#  'systemat review smart home literature: user perspect smart home; smart technology; systemat literatur review; user perspect',
#  'new intellig system architectur energi save smart home smart homes; recommend systems; energi efficiency; cloud computing; web servic',
#  'design smart home manag system base mqtt fbp fbp; inform manag system; mqtt; smart home',
#  'privacyguard: enhanc smart home user privaci iot privacy; smart home; machin learning; deep learn',
#  'smart home electr demand forecast system base edg comput smart homes; edg computing; short-term electr demand forecasting; intellig home gateway',
#  'sensemak autonom smart-home. smart-home; autonom computing; cybernet spaces; manag architecture; collabor',
#  'voic activ smart home design implement raspberri pi; python; smart home; telegram; alexa; alexa skill set',
#  'design smart homes: framework activ recognit home environ smart homes; internet things; activ recognition; cloud computing; multi agent system; analytics; wireless sensor actuat networks; wearabl wireless bodi sensor network',
#  'physic approach smart home proposit prototyp smart homes; physic approach; ubiquit computing; augment objects; home autom',
#  'smart home tracking: smart home architectur smart energi consumpt resid multipl user cloud services; internet things; middleware; mobil application; smart home',
#  'optim smart home perform user conveni rssi-bas proxim detect smart home; smarthome; smart home manag center; iot; rssi; ble',
#  'toward smart home authent use puf edge-comput paradigm iot; edg computing; smart home; puf',
#  'data model home servic context; data engineering; data models; knowledg engineering; semant web; smart homes; ubiquit comput',
#  'polici mix sustain smart home technolog smart home technologies; smart energi management; smart grids; smart meters; energi buildings; energi feedback; digit societi',
#  'smart energy-effici home implementation: wireless commun technolog role smart home; cloud-bas solutions; smart domest appliances; wireless protocol',
#  'platform prove famili orient rest servic host home home host services; rest home; home platform; digit home',
#  'design tensorflow-bas proactiv smart home manag iot; smart home manager; machin learning; tensorflow; logist classif',
#  'user-centr privaci infer detect smart home devic smart home; privacy; user-centr privacy; infer detect',
#  'smart home ivr-bas system south slavic languag integr smart home; ivr; voip; iot',
#  'cep-bas smart residenti servic system component; complex event processing; smart home system',
#  'smart home finger tip: osgi-bas myhom myhome; smart home; mom; osgi',
#  'model smart home elderli ambient intelligence; agents; elderly; refer net; time net; smart home',
#  'secur devic control scheme blockchain smart home smart home; devic control; spoofing; blockchain; zero-knowledg proof',
#  'smart remote: smart home manag solut child internet thing (iot); smart city; smart home system; embed computing; cloud data mining; fog computing; distribut data analyt',
#  'enhanc smart-hom environ use magentix2 multi-ag systems; norm environment; smart-hom',
#  'guideline-driven platform healthcar servic smart home environ telecare; guidelin interchang format (glif); home healthcar',
#  'cybersecur threat countermeasur smart home ecosystem smart home; cybersecurity; internet thing (iot); secur countermeasure; authent',
#  'cloud-bas monitor framework smart home component; cloud computing; smart home; remot monitor',
#  'design iot smart home system internet things; microcontrollers; smart home',
#  'trust-bas authent smart home system smart home; iot; authentication; jam attacks; clone attack',
#  'smart home sweet smart home: examin smart home accept pervas technology; privat settings; satisfaction; smart home; technolog accept',
#  'motivations, barrier risk smart home adoption: systemat literatur review conceptu framework smart home; home automation; domotics; smart living; internet-of-th (iot); technolog adopt',
#  'problem share iot servic within one smart home infrastructur iot; video surveillance; servic stabil',
#  'hybrid cloud architectur cross-platform interoper smart home cloud; iot; interoperability; smart home',
#  'smart home support integr health care servic older adult community: literatur review research agenda smart homes; ambient assist living; older adults; research agenda',
#  'toward in-network secur smart home internet things; smart homes; network security; attack mitigation; anomali detect',
#  'fuzzi logic control smart home energi storag provid activ reactiv power flexibl servic energi flexibility; tso; dso; smart homes; fuzzy; inverter; energi storag',
#  'composit context awar servic platform user-centr servic composit context; composit context awar servic platform; smart home service; user-centr servic',
#  'smart technolog valu cocreat custom engag smart energi servic smart energi services; custom engagement; valu cocreation; smart grids; esco',
#  'data-driven understand smart servic system text mine smart service; smart system; smart servic system; text mining; data-driven understand',
#  'wire smart home: energi metering, security, emerg issu m2m m2m; smart home; etsi; open metering; web servic',
#  'control servic robot smart home behavior plan learn behavior planning; case-bas reasoning; context awar systems; servic robot',
#  'smart object detect home applianc control system smart citi hybrid deep learn model; iot; smart cities; home applianc control system; amazon web servic',
#  'model smart home affect cyberattack cyberattack; distribut energi resourc (ders); fals data inject (fdi); smart home',
#  'internet thing (iot) build smart home system iot platform architecture; smart home; machin machin commun',
#  'distribut id architectur model smart home system smart home; home gateway; intrus detect system; internet thing',
#  "bring 5g user' smart home smart home; home automation; 5g mobil networks; 5g mobil systems; 5g network slicing; femtocell; internet thing",
#  'time local system smart home use hierarch structur dynam frequenc smart home; time localization; rssi; mobil comput',
#  'privhome: privacy-preserv authent commun smart home environ smart home privacy; encrypt query; searchabl encrypt',
#  'rank secur iot-bas smart home consum devic security; smart homes; systematics; analyt hierarchi process; tv; network security; internet things; ahp; consum applications; cloud computing; home consum devices; network security; smart home',
#  'self-awar context smart home pervas platform self-awareness; context; service-ori pervas platforms; pervas applications; smart home',
#  'clicker: convert modern home smart modern home use iot iot; smart homes; aws; electr save',
#  'bridg universa echonet smart home environ system integration; syntax translation; universaal; echonet; smart home',
#  'overview iot-bas architectur model smart home system smart home; iot architecture; sensors; actuators; home appliances; wireless commun',
#  'implement smart home system base internet thing smart home system; zigbee; cloud server; mobil app.',
#  'icmpv6sd: compact servic discoveri protocol support plug-and-play home smart home; iot; servic discovery; upnp; ipv6; icmpv6',
#  'evalu user experi smart home contexts: methodolog framework smart home; affordance; user experi',
#  'smart home forensics-data analysi iot devic digit forensics; smart homes; data analysis; internet thing',
#  'smart home security: challenges, issu solut differ iot layer smart cities; smart home; security; iot; protocol',
#  'develop control energi usag inform modul smart home tibbo; hybrid smart home',
#  'osgi-bas smart home architectur heterogen network osgi; upnp; dpws; smart home; soa',
#  'smart effici health home system smart homes; intellig systems; effici health homes; microcomputer-bas system',
#  'abstract heterogen iot devic manag smart home abstraction; internet things; smart home',
#  'secfhome: secur remot authent fog-en smart home environ fog computing; smart home; authentication; security; lightweight',
#  'improv iot servic smart-hom use blockchain smart contract',
#  'smart home inform manag system energy-effici network energy-effici networks; interoper smart home system (shs); internet thing (iot); virtual enterpris (ve); energy-control servic',
#  'smart home architectur design cyber physic system cyber physic systems; smart home; real-tim control; architectur',
#  'novel architectur effici commun smart grid home area network damgard jurik scheme; home area network; zigbee; denial service; smart meter',
#  'optim smart gateway deploy internet thing smart home environ internet thing (iot); smart home; binari integ program',
#  'user-guid person methodolog facilit new smart home occup smart home; system adaptation; transfer learning; system personalis',
#  'activ recognit new smart home environ activ recognition; smart home; binari sensor; health care; transfer learn',
#  'rotat roll-call-bas adapt failur detect recoveri protocol smart home environ failur detection; failur recovery; smart home',
#  'secur smart home network software-defin perimet smart home networks; security; privacy; do attack; software-defin perimet (sdp)',
#  'secur privaci implement smart home: attribut base access control smart contract blockchain; smart home; access control; smart contract; cyber threat',
#  'homepad: privacy-awar smart hub home environ smart home; privacy; internet things; data flow analysis; smart home devic',
#  'design goal-ori smart-hom environ multi-ag systems; smart-hom environments; adapt systems; goal-ori systems; service-ori system',
#  'smart devic inform extract home wi-fi network deep packet inspection; inform extraction; smart home; udf; user agent',
#  'design emot majormodo smart home healthcar affect computing; smart home; embodi convers agent; human-comput interact',
#  'novel smart home authent protocol lrp-shap smart home; remot control; security; authentication; key manag',
#  'internet-of-th smart home elderli healthcare: end user perspect elderly; healthcare; smart home',
#  'appli technolog smart home applic health sector smart home; well-being; elderli people; health sector',
#  'poster: decis make support privaci data upload smart home privacy; privaci control; smart home; k-anonymity; iot',
#  'deploy 5g-technolog smart citi smart home wireless sensor network interfer 5g-technology; smart city; smart home; wireless sensor networks; interferences; cognit radio',
#  'embrac smart-hom revolut asia elderly: end-us neg percept model elderly; iot; neg percept modeling; resistance; smart-hom servic',
#  'optim plan electr applianc residenti unit smart home network use cloud servic energi storage; electr appliance; home area energi manag system (haems); neural network; renew energi resources; smart citi',
#  'social network smart home smart home; social network sites; facebook; pervas computing; embed devices; inform appliances; web services; rest',
#  'creat smart environments: analysi improv secur smart home iot; intellig systems; smart home; smart hub; smart enviroment; inform security; geograph inform',
#  'inconsist detection-bas lod smart home conflict management; inconsist detection; internet things; lod; profile; smart home; thesauru',
#  'iot delegate: smart home framework heterogen iot servic collabor heterogen devic network; application-level collaboration; program model',
#  'scheme sensor data reconstruct smart home smart home; data restoration; data availability; data interpolation; home sensor',
#  'intellig energi inform servic base multi-hom environ smart home system; energi efficiency; energi management; smart appliances; intellig servic',
#  'activ base end-user-develop smart homes: relev challeng end user programming; end user development; activ theory; smart homes; smart environ',
#  'interconnect commun recognit autom servic home grid smart grid; home grid; applianc recognit',
#  'framework energy-effici smart home environ energi efficiency; smart home environ (she); interoper home energi manag system (hems); inform manag model; energi consumpt forecast',
#  'internet person autonom thing (iopat) smart home case studi person iot; autonom systems; smart home',
#  'abnorm detect approach smart home use case-bas reason smart home; case-bas reasoning; abnorm situat',
#  'automat detect sensit data smart home smart home; privaci violation; pool-bas activ learn',
#  'explain activ recognit smart home system explain ai; smart home activ recognition; human-ai-interact',
#  'iot-bas user-centr ecosystem heterogen smart home environ indoor localization; iot; middleware; m2m; smart home',
#  'anonym secur framework connect smart home environ smart home; internet things; anonymity; key agreement; unlink',
#  'energi effici iot-bas smart home iot; smart home; energi efficient; multi-band antenna; hvac; led; compact print antennas; thermal management; energi effici',
#  'home applianc control smart tv set-top box screen-mirror remot control home applianc controlling; home automation; smart tv; screen-mirro remot control',
#  'jarvis: voice-bas context-as-a-servic mobil tool smart home environ internet thing (iot); context definit queri languag (cdql); smart home',
#  'iot base smart home applianc use cloud intellig tetri switch cloud; internet thing (iot); home appliance; smart home; switch',
#  'design smart home environ monitor system base raspberri pi smart home environ monitoring; smart home controller; enocean wireless sensor control network; b/ architecture; data commun protocol',
#  'effect polici share mechan smart home network internet things; iot policies; smart homes; network manag',
#  'rule-bas framework heterogen subsystem manag smart home environ eca; smart home; soap',
#  'conceptualis internet thing artifici intellig enabl smart home smart homes; artifici intelligence; internet things; sensor',
#  'present situat problem analysi smart commun nurs servic beij smart community; age population; commun nurs service; home-bas elderli care',
#  'secur smart home: real case studi enforcement; internet things; security; smart home; sticki polici',
#  'new approach secur analysi smart home authent system smart home; wireless sensor networks; security; attack graph',
#  'container architectur edg comput smart home containers; deep learn model; edg computing; dockers; micro service; distribut computing; smart home',
#  'intellig devic disambigu smart home control devic disambiguation; voic assistants; smart homes; multi devic classification; xgboost',
#  'fog comput base router-distributor applic sustain smart home smart home; sustainability; fog computing; smart router; cloud comput',
#  'petri-net base context-awar workflow system smart home petri-net; workflow; smart home; context-awar',
#  'applic natur languag process iotcloud smart home cloud computing; iot; nlp; smart home autom',
#  'smart home elder care use wireless sensor independ living; activ monitor sensors; e-health servic development; smart home',
#  'rohini: robot flower system intuit smart home interfac human robot interaction; intuit interface; biomimet sensing; robot flower; smart home',
#  '- - know smart home: analysi smart home literatur smart home; qualit meta-analysis; literatur review; service-technology-organization-fin model (stof)',
#  'implement pervas comput base high-secur smart home system smart home; gsm; wi-fi; zigbee; context-aware; smart sensor; pervas comput',
#  'context reason smart home use case-bas reason context-awar system; smart home; ontology; case-bas reasoning; osgi',
#  'indoor localization-bas energi manag smart home energi management; indoor localization; smart home; bluetooth low energi',
#  'echonet lite-bas iot platform smart home iot platform; smart home; echonet lite protocol; mqtt protocol; jwt-base authent',
#  'foresight - platform approach enabl ai-bas servic smart live artifici intelligence; ecosystem; platform; smart home; smart live',
#  'applic learn algorithm smart home iot system secur machin learning; smart home; security; internet thing',
#  'approach data privaci smart home use blockchain technolog smart home; blockchain; ethereum; smart contract; internet things; privaci',
#  'design implement middlewar smart home gateway base sip smart home gateway; sip; middlewar',
#  'novel enhanc lorawan framework smart home remot control secur smart home; lorawan; security; key manag',
#  'explor critic qualiti attribut model smart home smart home; kano model; home entertainment; home security; home automation; theori plan behavior',
#  'framework servic robot smart home: effici solut domest healthcar servic robots; smart home; healthcare; task planner; context acquisition; ontology; activ recognit',
#  'human activ recognit via recogn bodi part human depth silhouett resid monitor servic smart home human activ recognition; depth silhouettes; recogn bodi parts; smart home',
#  'real-tim smart safe-return-hom servic base big data analyt safe-return service; safe-return-hom service; big data analyt',
#  'analysi malici threat agent smart connect home connect home; iot; smart home; threat agent; threat agent motivations; threat agent capabl',
#  'ontology-bas smart home solut servic composit',
#  "novel predict home appliance' manag algorithm smart grid smart grid; electricity; scheduling; adaptive; smart home; non-preempt scheduler; preemptiv schedul",
#  'research smart home energi manag system demand side management; final customer; smart metering; smart grids; home automation; refer architecture; distribut gener',
# ...
#  'effici solut smart home applic cloud; data aggregation; iot; smart home; smart meter',
#  'hybrid user-assist increment model adapt activ recognit dynam smart-hom environ activ learning; activ recognit (ar); dynam environment; smart home; system adaptability; user prefer',
#  'live servic (laas): experi evalu live experi connect home netherland smart home; behavior factors; user journey; user persona',
#  'context-awar healthcar system base iot - smart home caregiv system (shcs) context-aware; internet things; health care; smart home caregiv system (shcs); represent state transfer (rest)',
#  'servic manag converg autom network support health sustain applic smart home; build auomtation; servic class; quailti servic (qos); wimax',
#  'smart home energi plan use iot cloud smart grigridd; energy; demand manag',
#  'eps: effici privacy-preserv servic search scheme smart commun internet things; smart community; privaci preservation; cooper network',
#  'anomali detect smart grid traffic data home area network smart grid; anomali detection; k-mean cluster',
#  'toward effici resourc util exploit collabor hpf 5g enabl energi manag control smart home cloud fog computing; respons time; request service; smart grid; microgrid; virtual machin',
#  'waca: wearabl devic base home control assist framework wearable; wearabl device; smart watch; devic control; smart home; smart build',
#  'plug play iot wi-fi smart home system human monitor smart homes; internet thing (iot); wi-fi; human monitoring; behavior analysi',
#  'approach smart hous servic',
#  'home energi forecast perform tool smart live servic supplier energi 4.0 cp framework industri 4; 0; energi management; smart grids; artifici neural networks; smart home; smart meter; forecast',
#  'ambient ecolog smart home ubiquit computing; intellig systems; formal model; context-awar artifacts; middleware; synapse-ori program',
#  'identifi key driver barrier smart home adoption: themat analysi busi perspect smart homes; in-depth interview; qualit research; iot; internet things; themat map',
#  'rssi-bas indoor local identif zigbe wireless sensor network smart home ambient-assist live (aal); home autom system; identification; localization; receiv signal strength indic (rssi); smart homes; wearabl device; wireless sensor network; zigbe',
#  'privacy-preserv data infrastructur smart home applianc base octopu dht privacy; home appliances; rfid; p2p',
#  'softwar analysi use visual technic function control smart home care analysis; visualization; control; smart home care; softwar',
#  "healthcar providers' perspect use smart home system improv self-manag care peopl heart failure: qualit studi cardiovascular diseases; heart failure; inform technology; smart home systems; health technology; healthcar profession",
#  'determin inform commun smart home autom technolog adopt aging-in-plac assist technology; inform commun technology; structur equat modeling; smart home; aging-in-place; home autom',
#  "integr technolog accept model maslow' hierarchi need theori investig smart home adopt smart home; technolog accept model; maslow' hierarchi need theory; technolog adoption; purchas intent",
#  'use malwar software-defin networking-bas smart home secur manag taint check approach mobil security; taint checking; software-defin networking; dynam taint propagation; smart home system',
#  'cloud thing (cot) base secur home area network (han) smart grid key management; cloud things; smart grid; cyber-attack; han',
#  'optim power usag smart nurs home environ medic services; featur extraction; older adults; power demand; training; costs; optimization; elderli care; energi efficiency; self-cogniz prognostics; smart build',
#  'perceiv valu evalu smart product-servic system smart kitchen applianc smart pss; user experience; perceiv value; scale development; smart kitchen appliances; new product development; system engineering; technolog manag',
#  'effici privacy-preserv authent techniqu base conform fraction chaotic map tmi smart home environ healthcar systems; authent key agreement; tmis; smart homes; conform fraction chaotic map; security; anonym',
#  'unlock smart home: explor key factor affect smart lock adopt intent innovation; end users; adoption; artifact; access control; ubiquit system',
#  'fine-grain conflict detect iot servic iot services; multi-resid smart home; fine-grain conflict detection; entropy; inform gain',
#  'jamura: convers smart home assist built telegram googl dialogflow web things; convers agents; home automation; intellig decision-making; chatbot',
#  'usag wifi lte smart grid smart grid; wireless networks; smart home',
#  'cybersecur smart home systems: sensor ident protect ident theft; intrus detection; sensit environment; cybersecurity; cyber-attacks; machin learning; internet-of-th',
#  'service-ori pervas platform support machin learn applic smart build smart building; machin learning; service-ori pervas platform; industri 4.0',
#  'repres tempor depend smart home activ recognit health monitor human activ recognition; tempor dependency; smart homes; sensors; ambient assist live',
#  'demand side manag servic smart build use second gener smart meter chain-2 e-distribuzion smart grid; smart buildings; dsm; smart meter; chain-2; home autom',
#  'factor predict accept adopt smart home technolog senior australia: structur equat model longitudin data utaut; accept adopt models; australian; seniors; smart home technolog',
#  'gpr enabl smart energi meter -home display applic time use price arduino; home display; smart energi meter; labview; harmon analysis; time use price',
#  'behavior predict use improv hidden markov model support peopl disabl smart home behavior prediction; peopl disabilities; smart home; improv hidden markov model',
#  'ubiquit comput ambient intellig smart home applic component; ubiquit computing; ambient intelligence; smart home applications; pandora rout algorithm; wireless hybrid networks; wireless sensor network',
#  'autom system architectur smart hotel smart hotel; sensor networks; automation; cloud services; smart system',
#  'smart home system: comprehens review',
#  'digihom service-ori platform sca; context-awareness; smart home',
#  'valu co-creat virtual smart build servic enterpris energi effici econom sustain energi efficiency; smart building; smart build management; valu co-creat',
#  'smart grid monitor servic differenti via epon wireless sensor network converg ethernet passiv optic networks; fiber-wireless networks; gateway design; qualiti service; smart grid; wireless sensor network',
#  'barrier provid internet-bas home care servic urban older adult china: qualit studi servic provid internet-bas home care services; servic providers; urban older adults; barriers; qualit studi',
#  'home edg comput architectur smart sustain agricultur breed home edg comput (hec); edg comput systems; ultra-low latency; internet thing (iot); smart agriculture; edgecloudsim',
#  'internet thing enabl multi sensori tv smart home qualiti experience; object & subject evaluation; futur broadcast servic',
#  'new consum servic provid smart meter',
#  'interoper benefit challeng smart citi services: blockchain solut blockchain; iot; secur privacy; smart home; distribut ledger technolog',
#  'bacnet gateway embed web servic bacnet; dpws; gateway; build automation; smart home; embed devices; smart environ',
#  'provid mainstream smart home technolog assist technolog person disabilities: qualit studi profession mainstream smart home technology; assist technology; assist technolog servic delivery; peopl disabilities; semi-structur interview',
#  'research design implement smart home system base arm zigbe techniqu analysi data transmiss secur enhanc model smart home system; arm zigbee; data transmission; secur enhanc',
#  'self-adapt system develop method smart control system cp autonom computing; home servic robot; intellig system; self-adapt system; smart control system',
#  'three-met amr system grid demand-sid energi manag smart home system amr system; wireless networks; grid demand-sid energi management; smart home',
#  'symbiosi evolut model behavior multipl resourc agent smart elderli care servic ecosystem symbiosi evolut model; multipl resourc agents; smart elderli care servic ecosystem; comput simulations; chines case',
#  'design implement secur system smart home base iot technolog smart home; internet things; nb-iot; wifi',
#  'compress reced horizon approach smart home energi manag home appliances; optim scheduling; smart homes; resourc management; uncertainty; state charge; programming; home energi water manag systems; mixed-integ programming; optim scheduling; reced horizon; smart home',
#  'homenetrescue: sdn servic troubleshoot home network wireless networks; softwar defin wireless networks; home automation; comput network manag',
#  'comprehens review iot network technolog smart home autom applic wireless sensor network (wsn); internet thing (iot); home automation; smart home; lpwan; home networks; network technolog',
#  'develop smart home solut base person intellig interior unit promot activ custom healthcar age societi activity; assist technology; person intellig interior units; sens technology; smart furniture; smart home',
#  'energi manag strategi smart home regard uncertainties: state art, trends, challeng smart home; stochast energi scheduling; uncertainties; plug-in electr vehicle; photovolta array; heat pump',
#  'unifi framework activ recognition-bas behavior analysi action predict smart home activ recognition; smart homes; behavior analysis; action prediction; lifestyl analysis; u-healthcar',
#  'busi servic model smart home applianc particip peak shave valley fill base cloud platform power system; peak shave valley filling; home applianc busi resources; busi model; load aggreg',
#  'human activ recognit smart homes: combin passiv rfid load signatur electr devic comput intelligence; smart home; activ recognition; passiv rfid; load signatur applianc',
#  'adapt priority-bas conflict resolut iot servic iot service; multi-resid smart home; adapt priority; analyt hierarchi process; conflict resolut',
#  'toward energi effici home automation: deep learn approach smart homes; energi management; internet things; machin learn',
#  'qoe-awar servic composit smart citi use rest iot internet things; sniart city; qualiti experience; servic composit',
#  'secur user authent key agreement scheme iot devic access control base smart home commun internet thing (iot); authentication; key agreement; smart home; security; devic access control; attack',
#  'design implement cloud-iot-bas home energi manag system home energi manag system; smart home; internet things; cloud infrastructur',
#  'literatur review green smart home deliveri problem urban environ green logistics; home deliveri problem; last-mil problem; multi-mod fleet; vrp',
#  'toward elderli care: phase-difference-of-arriv assist ultra-wideband posit method smart home senior citizens; smart homes; ultra wideband technology; smart phones; sensors; wireless fidelity; antenna measurements; phase-difference-of-arriv (pdoa); location-bas servic (lbss); ultra-wideband (uwb) positioning; smart home; indoor posit',
#  'defens program smart home cybersecur',
#  "iot make life simpler: improv chines consumer' intent use lg homnet smart home influenc factors; lg homnet smart home; perceiv risk theory; purchas intention; tam",
#  'wifi-bas smart home fall detect system use recurr neural network wireless fidelity; senior citizens; smart homes; wearabl sensors; indoor environments; discret wavelet transforms; artifici intelligence; channel state information; data processing; mobil applications; smart homes; wireless communication; web servic',
#  'safe: secur applianc schedul flexibl effici energi consumpt smart home iot altern direct method multipli (admms); applianc scheduling; paillier cryptosystem; smart home (sh)',
#  'adapt interfac interact electron devic smart home control devices; tele-care; interact tv; smart home; interactive; adapt interfac',
#  'smart-hom environ support homework activ child adhd; environment monitor sensing; human-machin interaction; intellig objects; intellig things; internet things; robot assistance; smart-hom environ',
#  'studi design smart embed home system base wireless electr power measur monitor system wireless; home networking; embed system',
#  'cruis cabin home: smart approach improv cabin comfort smart cabin; application; comfort; iot devic',
#  'design implement servic framework presenc sens home network system presenc sensing; home network system; infrar motion sensor; web service; smart system',
#  'parameter privacy-awar pub-sub system smart work smart home technology; pub-sub system; privaci prefer',
#  'feature-bas knowledg transfer framework cross-environ activ recognit toward smart home applic activ recognit (ar); feature-bas knowledg transfer framework; smart home; transfer learn',
#  'desco: detect emot smart command audio; emot detection; machin learning; smart home; voic command',
#  'foresight - user-cent person privaci secur approach smart live activ assist living; gaia-x; smart home; smart live',
#  'heurist statist predict algorithm survey smart environ predict algorithms; smart cities; smart servic',
#  'implement design smart home achiev energi conserv',
#  'perform administr task multipl home autom gateway smart home; user experience; cloud; gateway; administr task',
#  'indoor human detect track use advanc smart floor smart home; pressur sensit floor sensor; human track',
#  'multipl warn smart monitor system use wearabl devic home care home care system; real-tim medic supports; vital sign analysis; cloud-bas systems; remot medic solut',
#  'context sensit access control smart home environ',
#  'studi smart power control algorithm use rf commun smart home environ',
#  'design implement smart home use sensor network',
#  'service-ori monitor system base rule evalu home autom consist checking; monitor services; linear tempor logic; home automation; smart home',
#  'resili technolog divers smart home graph-theoret approach model iot system integr heterogen network smart home; scienc security; graph analysis; modeling; network resilience; futur networks; internet thing (iot)',
#  'implement virtual agent interfac smart home voic control smart home; voic interface; hand free; mmdagent; microphon array',
#  'design perform analysi power line commun network impuls nois smart home achiev rate; impuls noise; outag probability; power line communications; smart home',
#  'appliancenet: neural network base framework recogn daili life activ behavior smart home use smart plug daili activities; home appliances; healthcar applications; intellig data processing; time-seri analysi',
#  'smart service-awar wireless mixed-area network',
#  'service-ori architectur ambient-assist live service-ori architecture; smart home; smart object; ambient-assist intelligence; ambient-assist live',
#  'determin locat applianc multi-hop tree structur power strip type smart meter smart grid; smart meter; ami; home network; smart power strip',
#  'evalu feasibl image-bas cognit api home context sens smart home; contexts; cognit api; document similar',
#  'smart grid secur concept issu smart grid; electr service; security; vulner',
#  'service-ori things: deliv smart servic use internet thing',
#  'understand patient activ pattern smart home process mine process mining; indoor locat system; smart homes; sensor',
#  'smart home secur camera shift line creepi design-l inquiri design inquiry; research design; critic hci; privacy; surveillance; smart home; smart city; internet thing (iot)',
#  'multiobject optim plan servic area smart parcel locker facil logist last mile deliveri smart parcel locker; logist last mile delivery; e-commerce; home delivery; nondomin sort genet algorithm ii',
#  'voic control smart mirror multifactor authent smart mirror; raspberri pi; artifici intelligence; voic recognition; face recognition; internet things; alexa voic servic']
