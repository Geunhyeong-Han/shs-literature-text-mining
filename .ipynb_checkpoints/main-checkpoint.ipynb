# %% [markdown]
# ## Setting

# %% [markdown]
# ### Importing Dependencies

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\jjska\anaconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\jjska\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in c:\users\jjska\anaconda3\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\jjska\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\jjska\anaconda3\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: colorama in c:\users\jjska\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
import pandas as pd
import numpy as np

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_score
from sklearn.metrics.pairwise import cosine_similarity

from wordcloud import WordCloud

import matplotlib.pyplot as plt

# %%
nltk.download('stopwords')
nltk.download('wordnet')

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jjska\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\jjska\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ### Data Load & Cleaning

# %%
data = pd.read_csv("pilot_textming.csv")
data.head()
# Out:
#                                                Title  \
# 0  The development for Internet of Things smart h...
# 1  Service Provisioning Framework for Digital Sma...
# 2          SHSM: A Service Middleware for Smart Home
# 3  SDN-based multi-level framework for smart home...
# 4          Privacy-Aware Web Services in Smart Homes
#
#                                             Keywords  \
# 0                 IoT; smart home; service; platform
# 1  smart home; service provisioning; distributed ...
# 2  Smart Home; Service Middleware; Service Comput...
# 3  SDN; Smart home API; Smart services; Smart hom...
# 4    Policy; Privacy; Smart Home; Trust; Web service
#
#                                             Abstract
# 0  Internet of things smart home integrates autom...
# 1  Development and Management Framework of Smart ...
# 2  There emerges an increasing need to overcome t...
# 3  The smart home is a field that uses smart devi...
# 4  Smart homes can assist their inhabitants with ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Title     1000 non-null   object
#  1   Keywords  959 non-null    object
#  2   Abstract  999 non-null    object
# dtypes: object(3)
# memory usage: 23.6+ KB

# %%
data.dropna(subset=['Abstract'], inplace=True)
data.drop_duplicates(subset=['Title'], inplace=True)

# %%
data.shape
# Out:
# (998, 3)

# %%
def combine_2rd_columns(col_1, col_2):
    result = col_1
    if not pd.isna(col_2):
        result += " " + str(col_2)
    return result


# data = pd.read_csv("pilot_textming.csv")
data["text"] = data.apply(lambda x: combine_2rd_columns(x['Title'], x['Abstract']), axis=1)

df = data.loc[:, ['text']]
df.tail()
# Out:
#                                                   text
# 995  Understanding Patient Activity Patterns in Sma...
# 996  Smart Home Security Cameras and Shifting Lines...
# 997  Multiobjective Optimization for Planning the S...
# 998  Voice Controlled Smart Mirror with Multifactor...
# 999  Leveraging Smart Meter Data & Expanding Servic...

# %%
df.drop_duplicates(subset=['text'], inplace=True)

# %%
df.shape
# Out:
# (998, 1)

# %% [markdown]
# #### Data Preprocess

# %%
def preprocess_text(text):
    # 소문자 변환 및 토큰화 (단어 단위로 분할)
    tokens = text.lower().split()
    
    # Stopword 제거 및 Lemmatization 수행
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens if token not in stop_words]
    
#     # Stemming 수행 (Porter Stemmer 사용)
#     stemmer = PorterStemmer()
#     tokens = [stemmer.stem(token) for token in tokens]
    
    # 숫자 제거 및 재결합하여 문자열 반환
    processed_text = ' '.join([token for token in tokens if not token.isdigit()])
    
    return processed_text

df['processed_text'] = df['text'].apply(preprocess_text)
df = df.loc[:, ['processed_text']]
df.head()
# Out:
#                                       processed_text
# 0  development internet thing smart home service ...
# 1  service provisioning framework digital smart h...
# 2  shsm: service middleware smart home emerges in...
# 3  sdn-based multi-level framework smart home ser...
# 4  privacy-aware web service smart home smart hom...

# %%
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(df['processed_text'])
tfidf_matrix
# Out:
# <998x8346 sparse matrix of type '<class 'numpy.float64'>'
# 	with 82546 stored elements in Compressed Sparse Row format>

# %% [markdown]
# #### Selected only the word-features - based on TF-IDF(Python scikit-Learn Library)

# %%
# 상위 Docuement 당 TF-IDF 기반 상위 4개의 단어 추출 함수 정의

top_keywords_per_document = []
feature_names = tfidf_vectorizer.get_feature_names_out()

for i in range(len(df)):
    tfidf_scores = zip(feature_names, tfidf_matrix[i].toarray()[0])
    sorted_tfidf_scores = sorted(tfidf_scores,key=lambda x: x[1], reverse=True)
    top_keywords_per_document.append([keyword for keyword,_ in sorted_tfidf_scores[:4]])

# 전체 데이터셋에서 적어도 2번 이상 나온 키워드 추출하기 
all_keywords=[keyword for document in top_keywords_per_document for keyword in document]
selected_keywords=list(set(keyword for keyword in all_keywords if all_keywords.count(keyword) >=2))

# 선택된 키워드를 기반으로 Document-Term Matrix 생성
vectorizer=CountVectorizer(vocabulary=selected_keywords)
document_term_matrix=vectorizer.fit_transform(df['processed_text'])

# WordCloud 시각화 함수 정의 및 실행   
def visualize_wordcloud(keywords):
     wordcloud=WordCloud(background_color='white', width=800,height=400).generate(' '.join(keywords))
     plt.imshow(wordcloud.recolor(colormap='viridis',random_state=42),interpolation="bilinear")
     plt.axis("off")
     plt.show()

visualize_wordcloud(selected_keywords)
document_term_matrix
# Out:
# <998x587 sparse matrix of type '<class 'numpy.int64'>'
# 	with 29750 stored elements in Compressed Sparse Row format>

# %%
# # 재정규화된 TF-IDF 값으로 단어 분포 확인
# renormalized_tfidf_matrix = tfidf_matrix / tfidf_matrix.sum(axis=1)
# word_distribution_per_document = renormalized_tfidf_matrix.A # .A to convert sparse matrix to numpy array

# print("Word Distribution per Document:")
# for i in range(len(df)):
#     print(f"Document {i+1}:")
    
# word_distribution_pairs = zip(feature_names, word_distribution_per_document[i])
# sorted_word_distribution_pairs = sorted(word_distribution_pairs,key=lambda x: x[1], reverse=True)

# for word,distribution in sorted_word_distribution_pairs:
#         print(f"{word}: {distribution}")

# %% [markdown]
# #### Gaussian mixture model (GMM) Elimniated Type 1 & Type 2

# %%
# 키워드들의 TF-IDF 벡터를 가져옵니다.
selected_keywords_list = list(selected_keywords)
selected_keyword_indices = [np.where(feature_names == keyword)[0][0] for keyword in selected_keywords_list]
selected_tfidf_vectors = tfidf_matrix[:, selected_keyword_indices].toarray()

# GMM 클러스터링을 수행합니다. 
n_clusters = 100 # 임의로 설정한 클러스터 개수
gmm = GaussianMixture(n_components=n_clusters)
gmm.fit(selected_tfidf_vectors)

# 각 클러스터에 속하는 단어들의 리스트를 생성합니다.
clusters = [[] for _ in range(n_clusters)]
labels = gmm.predict(selected_tfidf_vectors)
for word, label in zip(selected_keywords_list, labels):
    clusters[label].append(word)

# 10번의 클러스터링 분석을 수행하고, 일관되게 중요하지 않다고 판단되는 단어들을 추출합니다.
non_important_words_sets = []
for _ in range(10):
    gmm.fit(selected_tfidf_vectors)
    labels = gmm.predict(selected_tfidf_vectors)
    
    # 가장 큰 클러스터를 '중요하지 않은' 단어들로 간주합니다.
    largest_cluster_label = np.bincount(labels).argmax()
    non_important_words_sets.append(set(word for i, word in enumerate(selected_keywords_list) if labels[i] != largest_cluster_label))

# 모든 실행에서 공통적으로 중요하지 않다고 판단된 단어들만 추출합니다.
common_non_important_words_set = set.intersection(*non_important_words_sets)

print("Common Non-Important Words:")
for word in common_non_important_words_set:
    print(word)

# 선택된 키워드 목록에서 공통적으로 중요하지 않은 단어들을 제거합니다.
final_selected_keywords_set = set(selected_keywords_list) - common_non_important_words_set

print("\nFinal Selected Keywords:")
for word in final_selected_keywords_set:
    print(word)
# Out:
# Common Non-Important Words:
# digital
# osgi
# neural
# social
# composition
# homes
# productivity
# m2m
# pir
# hsp
# case
# care
# householder
# pet
# preserving
# pervasive
# delay
# computing
# hbbtv
# ar
# platform
# embedded
# district
# fi
# home
# woo
# weight
# transmission
# identification
# metering
# speaker
# capable
# diffusion
# reasoning
# green
# music
# sharing
# load
# machine
# space
# progress
# nature
# connected
# jordan
# fog
# appliance
# hn
# dpws
# adaptive
# query
# analytics
# provisioning
# rfid
# personalized
# controlling
# standard
# robotics
# smart
# plc
# malware
# centered
# approach
# rf
# ws
# auto
# inside
# public
# interface
# infrastructure
# agreement
# universaal
# event
# defined
# bridging
# team
# interoperation
# intelligent
# station
# tv
# predictor
# ubiquitous
# recognition
# storage
# preference
# problem
# market
# joint
# wearable
# benefit
# architecture
# discovery
# shome
# beacon
# mobile
# artificial
# light
# isp
# cd
# authorization
# south
# daily
# homecare
# body
# module
# available
# emergency
# electronic
# gateway
# residents
# resident
# robust
# technology
# line
# cross
# voice
# vendor
# willingness
# activity
# autonomy
# medical
# lifestyle
# classification
# ifttt
# robot
# original
# sensitive
# hns
# layer
# wsn
# cognitive
# processing
# sustainability
# profile
# level
# node
# technique
# ble
# evaluation
# data
# online
# thing
# context
# self
# electric
# real
# time
# video
# dependency
# expectancy
# multimedia
# physical
# interaction
# scenario
# strategy
# blockchain
# establishment
# ethereum
# delivery
# amr
# well
# oriented
# applying
# natural
# adoption
# flexible
# hierarchical
# gsm
# housing
# bandwidth
# cost
# innovation
# terminal
# driven
# being
# ecdh
# aged
# ml
# product
# meter
# added
# soa
# fall
# conflict
# optimal
# dynamic
# center
# attack
# item
# best
# reconfigurable
# mode
# assistive
# site
# utility
# upnp
# task
# forensic
# assessment
# game
# wsns
# key
# computation
# bacnet
# cep
# card
# relation
# dweller
# test
# eco
# logistics
# automation
# mirror
# rnn
# aging
# concept
# define
# localization
# inhabitants
# latency
# telecommunication
# control
# mobility
# shem
# authentication
# pv
# elderly
# sg
# consumption
# buildings
# carried
# pattern
# finger
# retrieval
# forensics
# arm
# enabled
# perceived
# content
# learning
# cloud
# private
# behaviour
# householders
# transfer
# function
# priority
# lighting
# qos
# medium
# der
# grained
# silhouette
# adaptation
# configuration
# non
# city
# future
# try
# local
# business
# depth
# company
# forecasting
# wi
# classifier
# sh
# peer
# end
# shhss
# acceptance
# edge
# ensemble
# nursing
# low
# compromised
# zero
# privacy
# new
#
# Final Selected Keywords:
# literature
# build
# uwb
# apis
# ontology
# modern
# awareness
# feedback
# fault
# contract
# domain
# living
# generation
# speech
# adl
# building
# allocation
# protocol
# availability
# bundle
# internet
# led
# power
# goal
# usage
# svm
# functionality
# application
# inhabitant
# communication
# situation
# residence
# project
# solution
# centric
# method
# signature
# consortium
# side
# anomaly
# cyber
# assisted
# survey
# attribute
# community
# cot
# optimization
# suitable
# phone
# deep
# issues
# rssi
# operation
# web
# toward
# score
# strip
# behavior
# throughput
# welfare
# ecosystem
# abnormal
# shas
# barrier
# language
# range
# safely
# app
# extraction
# fabric
# monitoring
# intention
# view
# exploited
# access
# belief
# networks
# zigbee
# component
# situations
# importance
# security
# quality
# senior
# perception
# middleware
# wifi
# mining
# sensing
# ai
# collaboration
# consumer
# face
# fine
# policy
# encryption
# algorithm
# use
# rule
# caring
# functional
# bus
# memory
# device
# emotional
# satisfaction
# integrated
# elder
# secret
# residential
# ahead
# may
# healthcare
# design
# object
# biophilic
# value
# sdn
# har
# pi
# sensorial
# controller
# multi
# factor
# ambient
# resilience
# challenge
# enocean
# unit
# field
# patient
# database
# traffic
# older
# upload
# expert
# client
# reality
# caregiver
# ddos
# net
# lot
# small
# scheme
# sensor
# external
# echonet
# wellbeing
# peak
# old
# pricing
# personality
# session
# hem
# next
# individual
# aware
# 20
# system
# nfv
# gesture
# knowledge
# methodological
# secure
# association
# decision
# attitude
# wot
# shss
# difference
# restful
# 15
# wireless
# planning
# topology
# health
# interconnected
# management
# integrating
# people
# energy
# physiological
# qoe
# collaborative
# iot
# raspberry
# person
# image
# action
# indoor
# technological
# aal
# like
# interoperability
# trust
# cybersecurity
# healthy
# detection
# continuous
# ownership
# network
# systematic
# in
# dissatisfaction
# experience
# found
# modeling
# service
# mesh
# model
# stage
# information
# agent
# wired
# process
# scheduling
# innovative
# datasets
# semantic
# enabling
# framework
# location
# element
# 5g
# passive
# intelligence
# screen
# top
# shs
# box
# household
# provider
# predicting
# customer
# wizard
# hems
# influence
# detailed
# positioning
# electrical
# icn
# server
# personalization
# shes
# domestic
# grid
# research
# gestures
# personal
# modelling
# floor
# motion
# mechanism
# offloading
# radio
# composite
# things
# generic
# programming
# hsr
# dc
# rental
# adult
# map
# development
# link
# usability
# heterogeneous
# graph
# resource
# devices
# concurrent
# software
# ui
# selection
# human
# hub
# threat
# environment
# cognition
# organizational
# switch
# integration
# virtual
# resolution
# theory
# proxy
# contextual
# dsm
# distributed
# enhancement
# inspired
# considered
# user
# protection
# prediction
# family
# deployment
# house
# electricity
# risk
# consumers
# remote
# assistance
# channel
# review
# pension
# industry
# 802

# %%
print(len(final_selected_keywords_set))
print(len(common_non_important_words_set))
# Out:
# 309
# 278

# %%
# Document-Term Matrix에서 각 키워드별로 평균 TF-IDF 값을 계산합니다.
vectorizer = TfidfVectorizer(vocabulary=final_selected_keywords_set)

tfidf_matrix = vectorizer.fit_transform(df['processed_text'])  # 'documents'는 문서 리스트입니다.

avg_tfidf_values = tfidf_matrix.mean(axis=0).A1  # 'A1'은 numpy array를 1차원으로 변환합니다.

keyword_tfidf_dict = dict(zip(vectorizer.get_feature_names_out(), avg_tfidf_values))

for word, value in keyword_tfidf_dict.items():
    if np.isnan(value):
        print(f"'{word}' has a TF-IDF value of NaN.")
        keyword_tfidf_dict[word] = 0
        
# 워드 클라우스 객체 생성
wordcloud = WordCloud(width=800, height=400, background_color='white')

# 선택된 키워트들과 그들의 평균 TF-IDF 값으로부터 워드클라우스 이미지 생성
wordcloud.generate_from_frequencies(frequencies=keyword_tfidf_dict)

# 워듣클라우스 시각화
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Document-Term Matrix에서 각 키워드별로 평균 TF-IDF 값을 계산합니다.
vectorizer = TfidfVectorizer(vocabulary=common_non_important_words_set)

tfidf_matrix = vectorizer.fit_transform(df['processed_text'])  # 'documents'는 문서 리스트입니다.

avg_tfidf_values = tfidf_matrix.mean(axis=0).A1  # 'A1'은 numpy array를 1차원으로 변환합니다.

keyword_tfidf_dict = dict(zip(vectorizer.get_feature_names_out(), avg_tfidf_values))

for word, value in keyword_tfidf_dict.items():
    if np.isnan(value):
        print(f"'{word}' has a TF-IDF value of NaN.")
        keyword_tfidf_dict[word] = 0
        
# 워드 클라우스 객체 생성
wordcloud = WordCloud(width=800, height=400, background_color='white')

# 선택된 키워트들과 그들의 평균 TF-IDF 값으로부터 워드클라우스 이미지 생성
wordcloud.generate_from_frequencies(frequencies=keyword_tfidf_dict)

# 워듣클라우스 시각화
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# #### Eliminated outliers by calculating the cosine similarities

# %%
# 1. TF-IDF 값을 다시 계산합니다.
vectorizer = TfidfVectorizer(vocabulary=final_selected_keywords_set)
tfidf_matrix = vectorizer.fit_transform(df["processed_text"])

# 2. 각 데이터 항목(문서) 간의 코사인 유사도를 계산합니다.
cosine_sim_matrix = cosine_similarity(tfidf_matrix)

# 3. 코사인 유사도가 특정 임곗값보다 높은(즉, 문서들이 매우 비슷한) 데이터 항목들을 제거합니다.
threshold = 0.8  # 임곗값 설정
outlier_indices = []

for i in range(len(df)):
    for j in range(i+1, len(df)):
        if cosine_sim_matrix[i][j] > threshold:
            outlier_indices.append(j)

# 중복된 인덱스 제거
outlier_indices = list(set(outlier_indices))

# 이상치 아닌 문서만 선택하여 최종 문서 집합 생성
final_documents = [doc for i, doc in enumerate(df["processed_text"]) if i not in outlier_indices]

# %% [markdown]
# ### Descriptive analysis - Spectral Clustering

# %%
from sklearn.decomposition import PCA
from sklearn.cluster import SpectralClustering
from sklearn.metrics import silhouette_score, pairwise_distances
import numpy as np
import matplotlib.pyplot as plt

# 선택된 키워드에 대한 TF-IDF 벡터 생성 및 PCA로 차원 축소 (2차원)
vectorizer = TfidfVectorizer(vocabulary=final_selected_keywords_set)
tfidf_matrix_selected_keywords = vectorizer.fit_transform(final_documents)
pca_model = PCA(n_components=2)
pca_result = pca_model.fit_transform(tfidf_matrix_selected_keywords.toarray())

# 클러스터 개수 범위 설정 (2부터 50까지)
cluster_range = range(2, 51)

# 각 클러스터 개수별로 Silhouette 평균 값을 기록할 리스트 초기화
silhouette_scores_cosine = []
silhouette_scores_euclidean = []

# PCA 결과를 기반으로 Spectral Clustering 및 Silhouette 계수 측정 반복
for n_clusters in cluster_range:
    silhouette_scores_per_cluster_cosine = []
    silhouette_scores_per_cluster_euclidean = []
    
    for _ in range(10):  # 10번 반복하여 평균값 구함
        # Spectral Clustering 모델 생성 및 학습 (코사인 유사도 기반)
        clustering_model_cosine = SpectralClustering(n_clusters=n_clusters, affinity='nearest_neighbors')
        cluster_labels_cosine = clustering_model_cosine.fit_predict(pca_result)

        # 거리 행렬 계산 (유클리디안 거리 기반)
        distance_matrix_euclidean = pairwise_distances(pca_result, metric='euclidean')

        # Spectral Clustering 모델 생성 및 학습 (유클리디안 거리 기반)
        clustering_model_euclidean = SpectralClustering(n_clusters=n_clusters, affinity='precomputed')
        cluster_labels_euclidean = clustering_model_euclidean.fit_predict(distance_matrix_euclidean)

        # Silhouette 계수 측정 및 기록 (코사인 유사도와 유클리디안 거리 두 가지 방법으로 각각 수행)
        silhouette_avg_cosine = silhouette_score(pca_result, cluster_labels_cosine) 
        silhouette_avg_euclidean= silhouette_score(distance_matrix_euclidean , cluster_labels_euclidean)
        
        silhouette_scores_per_cluster_cosine.append(silhouette_avg_cosine)
        silhouette_scores_per_cluster_euclidean.append(silhouette_avg_euclidean)

    # 각 클러스터 개수별로 Silhoutte 평균 값의 평균을 구함 (코사인 유사도)
    avg_silhouette_score_cosine= np.mean(silhouette_scores_per_cluster_cosine)
    silhouette_scores_cosine.append(avg_silhouette_score_cosine)

    # 각 클러스터 개수별로 Silhoutte 평균 값의 평균을 구함 (유클리디안 거리)  
    avg_silhoutte_score_Eucildean= np.mean(silhouette_scores_per_cluster_euclidean)
    silhouette_scores_euclidean.append(avg_silhoutte_score_Eucildean)


# 클러스터 개수에 따른 Silhoutte 평균 값 시각화 (코사인 유사도)
plt.plot(cluster_range,silhouette_scores_cosine, marker='o', label='Cosine Similarity')
plt.xlabel('Number of Clusters')
plt.ylabel('Average Silloute Score ')
plt.title('Silloute Score vs Number of Clusters - Cosine Similarity')

# 클러스터 개수에 따른 Silloute Average 점 수 시각화(유클라이드 거리) 
plt.plot(cluster_range,silhouette_scores_euclidean, marker='o', label='Euclidian Distance ')
plt.xlabel('Number of Clusters')
plt.ylabel('Average Silloute Score ')
plt.title('Silloute Score vs Number of Cluster - Euclidian Distance ')

# 범례 추가 
plt.legend()

# 그래프 출력
plt.show()
# Out:
# C:\Users\jjska\anaconda3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:392: UserWarning: Exited at iteration 191 with accuracies
# [9.45890755e-15 1.03396877e-05 7.95432512e-06 8.69265076e-06
#  9.16731614e-06 1.00522475e-05 7.73997873e-06 1.85254333e-05
#  1.35200252e-05]
# not reaching the requested tolerance 1.4200806617736816e-05.
# Use iteration 191 instead with accuracy
# 9.554629381168412e-06.
#
#   _, diffusion_map = lobpcg(
# C:\Users\jjska\anaconda3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:392: UserWarning: Exited postprocessing with accuracies
# [7.87884939e-15 1.03397909e-05 7.95434221e-06 8.69270000e-06
#  9.16733728e-06 1.00523079e-05 7.73997903e-06 1.85164075e-05
#  1.35322039e-05]
# not reaching the requested tolerance 1.4200806617736816e-05.
#   _, diffusion_map = lobpcg(
# C:\Users\jjska\anaconda3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:392: UserWarning: Exited at iteration 329 with accuracies
# [6.71077174e-15 7.45019916e-06 7.94823326e-06 9.92775197e-06
#  8.49806005e-06 1.00017235e-05 1.02927296e-05 1.88114930e-05
#  1.39243310e-05]
# not reaching the requested tolerance 1.4200806617736816e-05.
# Use iteration 309 instead with accuracy
# 8.939589568134095e-06.
#
#   _, diffusion_map = lobpcg(
# C:\Users\jjska\anaconda3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:392: UserWarning: Exited postprocessing with accuracies
# [6.41269792e-15 6.21760997e-06 7.60883293e-06 1.04242253e-05
#  8.21579245e-06 1.03357764e-05 1.02181177e-05 1.02576061e-05
#  1.71783653e-05]
# not reaching the requested tolerance 1.4200806617736816e-05.
#   _, diffusion_map = lobpcg(
# C:\Users\jjska\anaconda3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:392: UserWarning: Exited postprocessing with accuracies
# [3.69403380e-13 9.55345754e-06 7.10876079e-06 1.07064872e-05
#  7.89148132e-06 7.44182911e-06 1.32876994e-05 8.78865603e-06
#  1.73294850e-05]
# not reaching the requested tolerance 1.4200806617736816e-05.
#   _, diffusion_map = lobpcg(
# C:\Users\jjska\anaconda3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:392: UserWarning: Exited at iteration 976 with accuracies
# [7.71846790e-05 2.42308873e-10 8.07241683e-06 8.72245863e-06
#  9.31170328e-06 7.82919243e-06 9.21290422e-06 7.74745875e-06
#  8.89368188e-06]
# not reaching the requested tolerance 1.4200806617736816e-05.
# Use iteration
-05]
# not reaching the requested tolerance 1.4200806617736816e-05.
#   _, diffusion_map = lobpcg(
# C:\Users\jjska\anaconda3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:392: UserWarning: Exited postprocessing with accuracies
# [4.80423260e-13 6.58349109e-06 9.49563320e-06 9.47359250e-06
#  7.98592640e-06 6.58629000e-06 6.60058682e-06 9.44266048e-06
#  9.82730031e-06 8.23903361e-06 6.97176073e-06 8.69662718e-06
#  8.03395364e-06 7.81076887e-06 1.17262688e-05 9.32588707e-06
#  9.69997117e-06 9.01076134e-06 7.89414423e-06 1.16982750e-05
#  1.21648043e-05 1.03925774e-05 8.56913225e-06 8.93549868e-06
#  1.00166475e-05 9.50900333e-06 8.03007341e-06 8.62783561e-06
#  8.03291523e-06 7.60565140e-06 8.32930540e-06 7.42591970e-06
#  1.52783786e-05]
# not reaching the requested tolerance 1.4200806617736816e-05.
#   _, diffusion_map = lobpcg(
# C:\Users\jjska\anaconda3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:392: UserWarning: Exited at iteration 378 with accuracies
# [3.63358445e-14 7.01176979e-06 8.62698963e-06 9.74982932e-06
#  8.30168295e-06 9.10522582e-06 8.79115776e-06 8.23441945e-06
#  7.76259537e-06 8.71928793e-06 7.00747712e-06 1.00456789e-05
#  9.57522100e-06 8.55864733e-06 1.09893984e-05 9.17461622e-06
#  7.62724846e-06 1.00059427e-05 1.12086821e-05 1.06567075e-05
#  8.51995393e-06 9.49825010e-06 9.02155768e-06 8.57280602e-06
#  1.07873968e-05 1.02458778e-05 1.06408246e-05 1.05884921e-05
#  9.44069759e-06 9.16208575e-06 2.23886001e-05 1.09700880e-05
#  1.32522359e-05]
# not reaching the requested tolerance 1.4200806617736816e-05.
# Use iteration 359 instead with accuracy
# 8.882789332970109e-06.
#
#   _, diffusion_map = lobpcg(
# C:\Users\jjska\anaconda3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:392: UserWarning: Exited postprocessing with accuracies
# [2.05560230e-14 6.78597282e-06 8.60814614e-06 8.86958056e-06
#  8.10595354e-06 9.14183373e-06 8.74761123e-06 8.21096613e-06
#  7.77014045e-06 8.64280136e-06 7.01673705e-06 1.00166134e-05
#  9.70460841e-06 8.67429969e-06 9.21723401e-06 9.24827780e-06
#  7.65967656e-06 9.98586243e-06 1.11380541e-05 9.57938399e-06
#  8.42839463e-06 9.52669043e-06 8.53662143e-06 8.27746936e-06
#  9.87084716e-06 9.69305254e-06 8.95014261e-06 9.92578020e-06
#  9.66280286e-06 8.74809943e-06 7.73389583e-06 1.49804253e-05
#  1.18335533e-05]
# not reaching the requested tolerance 1.4200806617736816e-05.
#   _, diffusion_map = lobpcg(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 35
#      33 # Spectral Clustering 모델 생성 및 학습 (유클리디안 거리 기반)
#      34 clustering_model_euclidean = SpectralClustering(n_clusters=n_clusters, affinity='precomputed')
# ---> 35 cluster_labels_euclidean = clustering_model_euclidean.fit_predict(distance_matrix_euclidean)
#      37 # Silhouette 계수 측정 및 기록 (코사인 유사도와 유클리디안 거리 두 가지 방법으로 각각 수행)
#      38 silhouette_avg_cosine = silhouette_score(pca_result, cluster_labels_cosine)
#
# File ~\anaconda3\lib\site-packages\sklearn\cluster\_spectral.py:778, in SpectralClustering.fit_predict(self, X, y)
#     756 def fit_predict(self, X, y=None):
#     757     """Perform spectral clustering on `X` and return cluster labels.
#     758
#     759     Parameters
#    (...)
#     776         Cluster labels.
#     777     """
# --> 778     return super().fit_predict(X, y)
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:790, in ClusterMixin.fit_predict(self, X, y)
#     772 """
#     773 Perform clustering on `X` and returns cluster labels.
#     774
#    (...)
#     786     Cluster labels.
#     787 """
#     788 # non-optimized default implementation; override when a better
#     789 # method is possible for a given clustering algorithm
# --> 790 self.fit(X)
#     791 return self.labels_
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\sklearn\cluster\_spectral.py:730, in SpectralClustering.fit(self, X, y)
#     721 n_components = (
#     722     self.n_clusters if self.n_components is None else self.n_components
#     723 )
#     724 # We now obtain the real valued solution matrix to the
#     725 # relaxed Ncut problem, solving the eigenvalue problem
#     726 # L_sym x = lambda x  and recovering u = D^-1/2 x.
#     727 # The first eigenvector is constant only for fully connected graphs
#     728 # and should be kept for spectral clustering (drop_first = False)
#     729 # See spectral_embedding documentation.
# --> 730 maps = spectral_embedding(
#     731     self.affinity_matrix_,
#     732     n_components=n_components,
#     733     eigen_solver=self.eigen_solver,
#     734     random_state=random_state,
#     735     eigen_tol=self.eigen_tol,
#     736     drop_first=False,
#     737 )
#     738 if self.verbose:
#     739     print(f"Computing label assignment using {self.assign_labels}")
#
# File ~\anaconda3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:313, in spectral_embedding(adjacency, n_components, eigen_solver, random_state, eigen_tol, norm_laplacian, drop_first)
#     311 laplacian *= -1
#     312 v0 = _init_arpack_v0(laplacian.shape[0], random_state)
# --> 313 _, diffusion_map = eigsh(
#     314     laplacian, k=n_components, sigma=1.0, which="LM", tol=tol, v0=v0
#     315 )
#     316 embedding = diffusion_map.T[n_components::-1]
#     317 if norm_laplacian:
#     318     # recover u = D^-1/2 x from the eigenvector output x
#
# File ~\anaconda3\lib\site-packages\scipy\sparse\linalg\_eigen\arpack\arpack.py:1697, in eigsh(A, k, M, sigma, which, v0, ncv, maxiter, tol, return_eigenvectors, Minv, OPinv, mode)
#    1695 with _ARPACK_LOCK:
#    1696     while not params.converged:
# -> 1697         params.iterate()
#    1699     return params.extract(return_eigenvectors)
#
# File ~\anaconda3\lib\site-packages\scipy\sparse\linalg\_eigen\arpack\arpack.py:560, in _SymmetricArpackParams.iterate(self)
#     558     else:
#     559         Bxslice = slice(self.ipntr[2] - 1, self.ipntr[2] - 1 + self.n)
# --> 560         self.workd[yslice] = self.OPa(self.workd[Bxslice])
#     561 elif self.ido == 2:
#     562     self.workd[yslice] = self.B(self.workd[xslice])
#
# File ~\anaconda3\lib\site-packages\scipy\sparse\linalg\_interface.py:232, in LinearOperator.matvec(self, x)
#     229 if x.shape != (N,) and x.shape != (N,1):
#     230     raise ValueError('dimension mismatch')
# --> 232 y = self._matvec(x)
#     234 if isinstance(x, np.matrix):
#     235     y = asmatrix(y)
#
# File ~\anaconda3\lib\site-packages\scipy\sparse\linalg\_eigen\arpack\arpack.py:944, in LuInv._matvec(self, x)
#     943 def _matvec(self, x):
# --> 944     return lu_solve(self.M_lu, x)
#
# File ~\anaconda3\lib\site-packages\scipy\linalg\_decomp_lu.py:147, in lu_solve(lu_and_piv, b, trans, overwrite_b, check_finite)
#     143     raise ValueError("Shapes of lu {} and b {} are incompatible"
#     144                      .format(lu.shape, b1.shape))
#     146 getrs, = get_lapack_funcs(('getrs',), (lu, b1))
# --> 147 x, info = getrs(lu, piv, b1, trans=trans, overwrite_b=overwrite_b)
#     148 if info == 0:
#     149     return x
#
# KeyboardInterrupt:
